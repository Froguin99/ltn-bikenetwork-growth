# %% [markdown]
# # Step 6 - Analysis of overall bicycle network results
# ## Project: Growing Urban Bicycle Networks with LTNs

# %% [markdown]
# This notebook takes the existing infrastructure, the results from Step 5 and calculates/analyzes a number of measures as an average across all the processed locations

# %%
# import libraries
from src import utils
PATH = utils.PATH # shortening the var name so that we don't have to change it below

# System
import os
import glob
import dill as pickle
from collections import defaultdict
import pprint
pp = pprint.PrettyPrinter(indent=4)
from tqdm.notebook import tqdm
from pathlib import Path
from collections import defaultdict
import yaml
import json
from pathlib import Path


# Math/Data
import numpy as np

# Plotting
import matplotlib.pyplot as plt
import textwrap
import matplotlib.pyplot as plt
from PIL import Image
import matplotlib.image as mpimg


# Geo
import osmnx as ox
ox.settings.log_file = True
ox.settings.requests_timeout = 300
ox.settings.logs_folder = PATH["logs"]
import geopandas as gpd

# %% [markdown]
# ## Preliminaries

# %% [markdown]
# ### Parameters

# %%
debug = False # If True, will produce plots and/or verbose output to double-check
# if not debug: # Only do this if sure the code is bug-free!
#     warnings.filterwarnings('ignore')
rerun_existing = True # If True, will re-run the costly analysis of existing infra even if files already exist.
rerun = True # If True, recompute the analysis. If false, just re-make the plots

# %%
params = yaml.load(
    open("../parameters/parameters.yml"), 
    Loader=yaml.FullLoader)
osmnxparameters = json.load(open("../parameters/osmnxparameters.json", "r"))
plotparam = json.load(open("../parameters/plotparam.json", "r"))
plotparam_analysis = json.load(open("../parameters/plotparam_analysis.json", "r"))

# %% [markdown]
# ### Network weighting by tags

# %%
tag_lts = json.load(open("../parameters/tag_lts.json", "r"))
distance_cost = json.load(open("../parameters/distance_cost.json", "r"))

# %% [markdown]
# ## Loading

# %% [markdown]
# ### Load Results

# %%
# Load all analysis JSONs
results_list = []
for fp in Path(PATH["results"]).rglob("*_analysis_results.json"):
    try:
        placeid = fp.parent.parent.name
        scenario = fp.parent.name
        with open(fp, "r") as f:
            data = json.load(f)
        data["placeid"] = placeid
        data["scenario"] = scenario
        results_list.append(data)
        print(f"Loaded {fp} with {len(data)} results")
    except Exception as e:
        print(f"Failed to load {fp}: {e}")

# Separate into list-based and scalar-based
list_data = defaultdict(list)
scalar_data = defaultdict(list)

for res in results_list:
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            list_data[key].append(val)
        elif isinstance(val, (int, float, np.number)):
            scalar_data[key].append(val)

# Compute aggregated means
overall_results = {}
for key, list_of_lists in list_data.items():
    max_len = max(len(lst) for lst in list_of_lists)
    padded = np.full((len(list_of_lists), max_len), np.nan)
    for i, lst in enumerate(list_of_lists):
        padded[i, :len(lst)] = lst
    overall_results[key] = np.nanmean(padded, axis=0).tolist()

for key, values in scalar_data.items():
    overall_results[key] = float(np.nanmean(values))
# Out:
# Loaded ..\..\bikenwgrowth_external\results\gateshead\current_ltn_scenario\gateshead_current_ltn_scenario_analysis_results.json with 2326 results
# Loaded ..\..\bikenwgrowth_external\results\gateshead\more_ltn_scenario\gateshead_more_ltn_scenario_analysis_results.json with 2322 results
# Loaded ..\..\bikenwgrowth_external\results\gateshead\no_ltn_scenario\gateshead_no_ltn_scenario_analysis_results.json with 2280 results
# Loaded ..\..\bikenwgrowth_external\results\newcastle\current_ltn_scenario\newcastle_current_ltn_scenario_analysis_results.json with 2340 results
# Loaded ..\..\bikenwgrowth_external\results\newcastle\more_ltn_scenario\newcastle_more_ltn_scenario_analysis_results.json with 2336 results
# Loaded ..\..\bikenwgrowth_external\results\newcastle\no_ltn_scenario\newcastle_no_ltn_scenario_analysis_results.json with 2290 results
# ...

# %% [markdown]
# # Saving Setup

# %%
folders_to_make = {"plots_overall_results": os.path.join(PATH["plots"], "overall_results"), "overall_results": os.path.join(Path(PATH["plots"]).parent, "overall_results")}
for key, base_path in folders_to_make.items():
    os.makedirs(base_path, exist_ok=True)
    PATH[key] = {scenario: os.path.join(base_path, scenario) for scenario in params["scenarios"]}
    for path in PATH[key].values():
        os.makedirs(path, exist_ok=True)

# %%
# empty dict to store results
overall_results_per_scenario = defaultdict(dict)

# %% [markdown]
# # Make plot matrix

# %%
plots_root = Path(PATH["plots"])
chosen_scenario = "current_ltn_scenario"
valid_places = ["newcastle", "gateshead", "sunderland", "north_tyneside", "south_tyneside"]

plot_order = [ "L_of_Investment", "abs_dev_from_random_length", "total_investment_cost", "abs_dev_from_random_investment_cost",
    "length_difference", "length_difference_deviation_from_random", "Investment_vs_Length",
    "additional_cyclenet_connected", "biketrack_connected__deviation_from_random", "size_of_lcc",
    "lcc_length_deviation_from_random", "size_of_composite_lcc", "composite_lcc_deviation_from_random",
    "num_components", "num_components_deviation_from_random", "street_coverage_m", "street_coverage_pct",
    "seed_coverage_analysis", "overlap_size_percent", "overlap_size_deviation_from_random",
    "directness", "global_eff", "local_eff", "avg_node_degree", "avg_node_degree_deviation_from_random",
    "allLengths", "TotalLengthsCycleNet"]

# rename to nicer names
column_titles = [ "Length Invested", "Length Invested (Deviation from Random)", "Investment Cost (Routed - Existing)", "Investment Cost (Deviation from Random)",
    "Length Differance", "Length Differance (Deviation from Random)", "Investment Cost Vs Length Cost", "Addtional Cycle Network Connected",
    "Addtional Cycle Network Connected (Deviation from Random)", "Length of LCC", "Length of LCC (Deviation from Random)", "Comp. LCC Size", "Comp. LCC (Deviation from Random)",
    "Number of Disconnected Components", "Number of Disconnected Components (Deviation from Random)", "Street Coverage (M)", "Street Coverage (% of streets)", "Seed Point Coverage",
    "Overlap with Existing %", "Overlap with Existing % (Deviation from Random)", "Directness", "Global Eff.", "Local Eff.",
    "Node Degree", "Node Deg (Deviation from Random)", "All Lengths", "CycleNet Total"]

for scenario in params["scenarios"]:
    print(f"Making matrix plot for scenario: {scenario}")
    # Load image paths
    place_to_plots = {}
    for place in valid_places:
        scenario_path = plots_root / place / scenario
        if scenario_path.exists():
            all_pngs = list(scenario_path.glob("*.png"))
            name_map = {p.stem: p for p in all_pngs}
            place_to_plots[place] = name_map

    n_rows = len(plot_order)
    n_cols = len(valid_places)
    fig = plt.figure(figsize=(2.5 * (n_cols + 1), 1.8 * n_rows), constrained_layout=True)
    gs = fig.add_gridspec(n_rows, n_cols + 1, width_ratios=[1] + [1] * n_cols, wspace=0.05, hspace=0.01)

    for row_idx, (plot_key, title) in enumerate(zip(plot_order, column_titles)):
        wrapped_title = "\n".join(textwrap.wrap(title, width=15))
        # Row labels
        ax_label = fig.add_subplot(gs[row_idx, 0])
        ax_label.text(0.5, 0.5, wrapped_title, ha="center", va="center", fontsize=8)
        ax_label.axis("off")
        for col_idx, place in enumerate(valid_places):
            ax = fig.add_subplot(gs[row_idx, col_idx + 1])
            plot_dict = place_to_plots.get(place, {})
            matched_path = plot_dict.get(plot_key)
            if matched_path and matched_path.exists():
                img = mpimg.imread(str(matched_path))
                ax.imshow(img)
            else:
                ax.text(0.5, 0.5, "Missing", ha="center", va="center", fontsize=8)
            ax.axis("off")

            if row_idx == 0:
                ax.set_title(place.replace("_", " ").title(), fontsize=10)

    plt.suptitle(f"{scenario.replace('_', ' ').title()} - All Metrics", fontsize=14)
    plt.savefig(Path(PATH["plots"]) / "overall_results" / scenario / "scenario_matrix_plot.png", dpi=800)
    plt.close()
# Out:
# Making matrix plot for scenario: no_ltn_scenario
# Making matrix plot for scenario: current_ltn_scenario
# Making matrix plot for scenario: more_ltn_scenario

# %% [markdown]
# # Lengths

# %% [markdown]
# Cycle network lengths

# %%
keys_labels = [('total_network_length', 'Fully Connected'),('total_biketrack_length', 'Biketrack'),('total_biketrack_no_ltn_length', 'Biketrack (no LTN)')]
scenario_results = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, _ in keys_labels:
        if key in res:
            scenario_results[scenario][key].append(res[key])

# Loop through each scenario and make plots
for scenario, data in scenario_results.items():
    means = {k: np.nanmean(v) for k, v in data.items()}
    overall_results_per_scenario[scenario].update({k: float(v) if not np.isnan(v) else None for k, v in means.items()})
    labels = [label for _, label in keys_labels]
    values = [means.get(key, np.nan) for key, _ in keys_labels]

    # Plotting
    plt.figure(figsize=(10, 6))
    plt.bar(labels, values)
    plt.xlabel('Network Type')
    plt.ylabel('Total Length (meters)')
    plt.title(f'Cycle Network Lengths – {scenario}')
    plt.tight_layout()
    output_path = os.path.join(PATH["plots_overall_results"][scenario], "cycleLengths_avg.png")
    plt.savefig(output_path, dpi=300)
    plt.show()

    # Print Stats
    print(f"\nScenario: {scenario}")
    for label, key, val in zip(labels, [k for k, _ in keys_labels], values):
        print(f"{label}: {val:.2f} m")
    if 'length_difference' in data:
        print(f"Difference in total length: {np.nanmean(data['length_difference']):.2f} m")

# Save overall results to JSON per scenario
for scenario, data in overall_results_per_scenario.items():
    output_json = os.path.join(PATH["overall_results"][scenario], "overall_summary_results.json")
    with open(output_json, "w") as f:
        json.dump(data, f, indent=2)
# Out:
# Scenario: current_ltn_scenario
# Fully Connected: 362525.68 m
# Biketrack: 204398.49 m
# Biketrack (no LTN): 106344.68 m
# Scenario: more_ltn_scenario
# Fully Connected: 321724.42 m
# Biketrack: 293099.00 m
# Biketrack (no LTN): 106344.68 m
# Scenario: no_ltn_scenario
# Fully Connected: 431940.89 m
# Biketrack: 106344.68 m
# Biketrack (no LTN): 106344.68 m

# %% [markdown]
# All network lengths

# %%
keys_for_all_lengths = ['total_biketrack_length', 'total_biketrack_no_ltn_length', 'total_network_length', 'total_investment_length']
scenario_results_all = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key in keys_for_all_lengths:
        if key in res:
            scenario_results_all[scenario][key].append(res[key])

# Loop through each scenario and make plots
for scenario, data in scenario_results_all.items():
    means = {k: np.nanmean(v) for k, v in data.items()}
    biketrack = means.get('total_biketrack_length', np.nan)
    biketrack_no_ltn = means.get('total_biketrack_no_ltn_length', np.nan)
    ltn_only = abs(biketrack - biketrack_no_ltn)
    full_network = means.get('total_network_length', np.nan)
    investment = means.get('total_investment_length', np.nan)

    labels = ["Existing Cycle Infrastructure (Including LTNs)",
        "Existing Cycle Infrastructure (Excluding LTNs)",
        "LTNs",
        "Fully Connected Cycle Network",
        "Investment Distance"]
    values = [biketrack, biketrack_no_ltn, ltn_only, full_network, investment]
    colors = ['deepskyblue'] * len(labels)

    # Add to overall_results_per_scenario
    overall_results_per_scenario[scenario].update({
        'ltn_only_length': float(ltn_only) if not np.isnan(ltn_only) else None,
        'length_comparison_labels': labels,
        'length_comparison_values': [float(v) if not np.isnan(v) else None for v in values]})

    # Plotting
    plt.figure(figsize=(12, 6))
    plt.bar(labels, values, color=colors)
    plt.xticks(rotation=15, ha='right')
    plt.xlabel('Network Type')
    plt.ylabel('Total Length (meters)')
    plt.title(f'All Network Lengths – {scenario}')
    plt.grid(True, axis="y", alpha=0.3)
    plt.tight_layout()
    output_path = os.path.join(PATH["plots_overall_results"][scenario], "allLengths_avg.png")
    plt.savefig(output_path, dpi=300)
    plt.close()

    # Print Stats
    print(f"\n[allLengths] Scenario: {scenario}")
    print(f"Fully connected network: {full_network:.2f} m")
    print(f"Biketrack: {biketrack:.2f} m")
    print(f"Biketrack (no LTN): {biketrack_no_ltn:.2f} m")
    print(f"LTN-only length: {ltn_only:.2f} m")
    print(f"Investment distance: {investment:.2f} m")

# Save overall results to JSON per scenario
for scenario, data in overall_results_per_scenario.items():
    output_json = os.path.join(PATH["overall_results"][scenario], "overall_summary_results.json")
    with open(output_json, "w") as f:
        json.dump(data, f, indent=2)
# Out:
# [allLengths] Scenario: current_ltn_scenario
# Fully connected network: 362525.68 m
# Biketrack: 204398.49 m
# Biketrack (no LTN): 106344.68 m
# LTN-only length: 98053.81 m
# Investment distance: 330247.05 m
#
# [allLengths] Scenario: more_ltn_scenario
# Fully connected network: 321724.42 m
# Biketrack: 293099.00 m
# Biketrack (no LTN): 106344.68 m
# LTN-only length: 186754.32 m
# Investment distance: 294993.07 m
#
# [allLengths] Scenario: no_ltn_scenario
# Fully connected network: 431940.89 m
# Biketrack: 106344.68 m
# Biketrack (no LTN): 106344.68 m
# LTN-only length: 0.00 m
# Investment distance: 392454.78 m

# %% [markdown]
# Investment length

# %%
# how much budget is used per iteration
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items(): # only series 
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            scenario_list_data[scenario][key].append(val)

# find mean across all locations for each scenario 
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        # pad to longest, then mean
        max_len = max(len(lst) for lst in lists)
        arr = np.full((len(lists), max_len), np.nan)
        for i, lst in enumerate(lists):
            arr[i, :len(lst)] = lst
        scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict

# set up for plotting
growth_orders = [("Random Growth (mean) - Total Investment Length", '--', 'blue', 'Random Growth (mean)'),
    ("Betweenness Growth - Total Investment Length", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Total Investment Length", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Total Investment Length", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Total Investment Length", '-', 'purple', 'Betweenness LTN Priority Growth')]

# plot and save
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))
    # individual random runs
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith("Total Investment Length") and "Deviation from Random" not in key:
            plt.plot(series, color='lightgray', linewidth=1, alpha=0.4)
 
    for key, ls, c, lbl in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=ls, color=c, label=lbl)
        else:
            print(f"[Warning] {scenario} missing {key}")
    plt.xlabel('Investment Iteration')
    plt.ylabel('Total Investment Length (meters)')
    plt.title(f'Length of Invested Cycle Network – {scenario}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # save
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "loInvestment_avg.png"), dpi=300)
    plt.show()

    # JSON dump of results
    included = [k for (k, *_ ) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith("Total Investment Length") and "Deviation from Random" not in k]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "loInvestment_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %%
# # how much budget is used per iteration
# plt.figure(figsize=(10, 6))
# plt.plot(overall_results['total_lengths'], linestyle='-', color='orange', label='Betweeness Growth')
# plt.plot(overall_results['random_total_lengths'], linestyle='--', color='blue', label='Random Growth')
# plt.plot(overall_results['demand_total_lengths'], linestyle='-.', color='red', label='Demand Growth')
# plt.xlabel('Investment Iteration')
# plt.ylabel('Total Length (meters)')
# plt.title('Length of Invested Cycle Network')
# plt.legend()
# plt.grid(True, alpha=0.3)
# plt.tight_layout()

# output_path = overall_results_path + "/loInvestment_avg.png"
# plt.savefig(output_path, dpi=300)

# plt.show()

# %% [markdown]
# "Actual" investment length

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():  # only series
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            scenario_list_data[scenario][key].append(val)

# Compute mean across locations
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        max_len = max(len(lst) for lst in lists)
        arr = np.full((len(lists), max_len), np.nan)
        for i, lst in enumerate(lists):
            arr[i, :len(lst)] = lst
        scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict


growth_orders = [
    ("Random Growth (mean) - Total Investment Length", '--', 'blue', 'Random Investment'),
    ("Betweenness Growth - Total Investment Length", '-', 'orange', 'Betweenness Investment'),
    ("Demand Growth - Total Investment Length", '-.', 'red', 'Demand Investment'),
    ("Demand LTN Priority Growth - Total Investment Length", ':', 'green', 'Demand LTN Priority Investment'),
    ("Betweenness LTN Priority Growth - Total Investment Length", '-', 'purple', 'Betweenness LTN Priority Investment')
]

# plot and save
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))

    # Plot individual random runs
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith("Total Investment Length") and "Deviation from Random" not in key:
            plt.plot(series, color='lightgray', linewidth=1, alpha=0.4)

    # Plot defined strategy lines
    for key, linestyle, color, label in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel('Investment Iteration')
    plt.ylabel('Total Investment Length (meters)')
    plt.title(f'Total Investment Required – {scenario}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "RequiredloInvestment_avg.png"), dpi=300)
    plt.close()

    # Save JSON dump
    included = [k for (k, *_ ) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith("Total Investment Length") and "Deviation from Random" not in k]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "RequiredloInvestment_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)
# Out:
# C:\Users\b8008458\AppData\Local\Temp\ipykernel_26180\3962620012.py:17: RuntimeWarning: Mean of empty slice
#   scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
# [Warning] no_ltn_scenario missing Demand LTN Priority Growth - Total Investment Length
# [Warning] no_ltn_scenario missing Betweenness LTN Priority Growth - Total Investment Length

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():  # only series
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            scenario_list_data[scenario][key].append(val)

# Compute mean across locations
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        max_len = max(len(lst) for lst in lists)
        arr = np.full((len(lists), max_len), np.nan)
        for i, lst in enumerate(lists):
            arr[i, :len(lst)] = lst
        scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict

# Set plotting order
growth_orders = [("Random Growth (mean) - Deviation from Random - Total Investment Length", '--', 'blue', 'Random Growth (mean)'),
    ("Betweenness Growth - Deviation from Random - Total Investment Length", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Deviation from Random - Total Investment Length", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Deviation from Random - Total Investment Length", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Deviation from Random - Total Investment Length", '-', 'purple', 'Betweenness LTN Priority Growth')]

# Plot and save per scenario
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith("Deviation from Random - Total Investment Length"):
            plt.plot(series, color='lightgray', linewidth=1, alpha=0.4)
    for key, linestyle, color, label in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel('Investment Iteration')
    plt.ylabel('Deviation from Random Investment (meters)')
    plt.title(f'Deviation from Random Investment – {scenario}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save figure
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "RequiredloInvestment_dev_from_random.png"), dpi=300)
    plt.close()

    # Save JSON of plotted data
    included = [k for (k, *_ ) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith("Deviation from Random - Total Investment Length")]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "RequiredloInvestment_dev_from_random.json"), "w") as f:
        json.dump(summary, f, indent=2)
# Out:
# C:\Users\b8008458\AppData\Local\Temp\ipykernel_26180\3880104621.py:17: RuntimeWarning: Mean of empty slice
#   scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
# [Warning] no_ltn_scenario missing Demand LTN Priority Growth - Deviation from Random - Total Investment Length
# [Warning] no_ltn_scenario missing Betweenness LTN Priority Growth - Deviation from Random - Total Investment Length

# %%
# # actual investment length
# plt.figure(figsize=(10, 6))
# plt.plot(overall_results['total_investment_lengths'],        '-',  color='orange', label='Betweeness Investment')
# plt.plot(overall_results['random_total_investment_lengths'], '--', color='blue',   label='Random Investment')
# plt.plot(overall_results['demand_total_investment_lengths'], '-.', color='red',    label='Demand Investment')
# plt.xlabel('Investment Iteration')
# plt.ylabel('Total Length (meters)')
# plt.title('Length of Investment Required')
# plt.legend()
# plt.grid(True, alpha=0.3)
# plt.tight_layout()

# output_path = overall_results_path + "/RequiredloInvestment_avg.png"
# plt.savefig(output_path, dpi=300)

# plt.show()

# %%
################################# Get rid?

# # both on one plot
# plt.figure(figsize=(10, 6))
# plt.plot(overall_results['investment_total_lengths'],        '-',  color='orange',    label='Betweenness (Invest)')
# plt.plot(overall_results['random_investment_total_lengths'], '--', color='blue',     label='Random (Invest)')
# plt.plot(overall_results['demand_investment_total_lengths'], '-.', color='red',      label='Demand (Invest)')
# plt.plot(overall_results['length_total_lengths'],            '-',  color='darkorange', alpha=0.7, label='Betweenness (Length)')
# plt.plot(overall_results['random_length_total_lengths'],     '--', color='darkblue',   alpha=0.7, label='Random (Length)')
# plt.plot(overall_results['demand_length_total_lengths'],     '-.', color='darkred',    alpha=0.7, label='Demand (Length)')

# plt.xlabel('Investment Iteration')
# plt.ylabel('Total Length (meters)')
# plt.title('Network size vs Investment required comparison')
# plt.legend()
# plt.grid(True, alpha=0.3)
# plt.tight_layout()

# output_path = overall_results_path + "/Required_vs_networksize_loInvestment.png"
# plt.savefig(output_path, dpi=300)
# plt.show()


# differance between total network size and investment required
# plt.figure(figsize=(10, 6))
# plt.plot(overall_results['length_differences'],         '-',  color='orange', label='Betweeness Growth')
# plt.plot(overall_results['random_length_differences'],  '--', color='blue',  label='Random Growth')
# plt.plot(overall_results['demand_length_differences'],  '-.', color='red',   label='Demand Growth')  # demand line
# plt.xlabel('Investment Iteration')
# plt.ylabel('Length Difference (meters)')
# plt.title('Difference between total network size and investment size required')
# plt.legend()
# plt.grid(True, alpha=0.3)
# plt.tight_layout()
# output_path = overall_results_path +  "/loInvestment_diff_avg.png"
# plt.savefig(output_path, dpi=300)

# plt.show()

# %% [markdown]
# Differance between network size and required investment

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            scenario_list_data[scenario][key].append(val)

# Compute mean across locations
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        max_len = max(len(lst) for lst in lists)
        arr = np.full((len(lists), max_len), np.nan)
        for i, lst in enumerate(lists):
            arr[i, :len(lst)] = lst
        scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict


growth_orders = [("Random Growth (mean) - Length Difference", '--', 'blue', 'Random Growth (mean)'),
    ("Betweenness Growth - Length Difference", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Length Difference", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Length Difference", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Length Difference", '-', 'purple', 'Betweenness LTN Priority Growth')]

# Plot and save
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith(" - Length Difference"):
            plt.plot(series, color='lightgray', linewidth=1, alpha=0.4)
    for key, linestyle, color, label in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel('Investment Iteration')
    plt.ylabel('Length Difference (meters)')
    plt.title(f'Length Difference Compared to Baseline – {scenario}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "length_difference_avg.png"), dpi=300)
    plt.close()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith(" - Length Difference")]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "length_difference_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %%
### missing length difference????

scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            scenario_list_data[scenario][key].append(val)

# Compute mean across locations
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        max_len = max(len(lst) for lst in lists)
        arr = np.full((len(lists), max_len), np.nan)
        for i, lst in enumerate(lists):
            arr[i, :len(lst)] = lst
        scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict

# Define plot ordering
growth_orders = [
    ("Random Growth (mean) - Deviation from Random Length Difference", '--', 'blue', 'Random Growth (mean)'),
    ("Betweenness Growth - Deviation from Random Length Difference", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Deviation from Random Length Difference", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Deviation from Random Length Difference", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Deviation from Random Length Difference", '-', 'purple', 'Betweenness LTN Priority Growth')]

# Plot and save
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))

    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith(" - Deviation from Random Length Difference"):
            plt.plot(series, color='lightgray', linewidth=1, alpha=0.4)
    for key, linestyle, color, label in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel('Investment Iteration')
    plt.ylabel('Deviation from Random (meters)')
    plt.title(f'Deviation from Random – Length Difference – {scenario}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "length_difference_absdev.png"), dpi=300)
    plt.show()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith(" - Deviation from Random Length Difference")]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "length_difference_absdev.json"), "w") as f:
        json.dump(summary, f, indent=2)
# Out:
# C:\Users\b8008458\AppData\Local\Temp\ipykernel_26180\2645170958.py:17: RuntimeWarning: Mean of empty slice
#   scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
# [Warning] no_ltn_scenario missing Random Growth (mean) - Deviation from Random Length Difference
# [Warning] no_ltn_scenario missing Demand LTN Priority Growth - Deviation from Random Length Difference
# [Warning] no_ltn_scenario missing Betweenness LTN Priority Growth - Deviation from Random Length Difference
# [Warning] current_ltn_scenario missing Random Growth (mean) - Deviation from Random Length Difference
# [Warning] more_ltn_scenario missing Random Growth (mean) - Deviation from Random Length Difference

# %%
# # investment cost vs physical network length

# plt.figure(figsize=(10, 6))
# plt.plot(
#     overall_results['lengths_list'], 
#     overall_results['investment_lengths_list'], 
#     '-', color='orange', label='Betweenness Growth'
# )
# plt.plot(
#     overall_results['random_lengths_list'], 
#     overall_results['random_investment_lengths_list'], 
#     '--', color='blue', label='Random Growth'
# )
# plt.plot(
#     overall_results['demand_lengths_list'], 
#     overall_results['demand_investment_lengths_list'], 
#     '-.', color='red', label='Demand Growth'
# )
# plt.xlabel('Total Length (meters)')
# plt.ylabel('Total Investment Length (meters)')
# plt.title('Investment Cost vs Physical Network Length')
# plt.legend()
# plt.grid(True, alpha=0.3)
# plt.tight_layout()
# output_path = overall_results_path + "/loInvestmentcost_vs_length_avg.png"
# plt.savefig(output_path, dpi=300)

# plt.show()

# %% [markdown]
# Distance gained

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            scenario_list_data[scenario][key].append(val)

# Compute mean across locations
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        max_len = max(len(lst) for lst in lists)
        arr = np.full((len(lists), max_len), np.nan)
        for i, lst in enumerate(lists):
            arr[i, :len(lst)] = lst
        scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict

growth_orders = [("Biketrack Random Mean - Connected Lengths", '--', 'blue', 'Random Growth (mean)'),
    ("Biketrack Connected Lengths", '-', 'orange', 'Betweenness Growth'),
    ("Biketrack Demand Connected Lengths", '-.', 'red', 'Demand Growth'),
    ("Biketrack Demand LTN Priority Connected Lengths", ':', 'green', 'Demand LTN Priority Growth'),
    ("Biketrack Betweenness LTN Priority Connected Lengths", '-', 'purple', 'Betweenness LTN Priority Growth')]

# Plot and save
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))

    # Plot random runs
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith(" - Biketrack Connected Lengths"):
            plt.plot(series, color='lightgray', linewidth=1, alpha=0.4)

    # Plot defined strategy lines
    for key, linestyle, color, label in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel('Investment Iteration')
    plt.ylabel('Biketrack Connected Length (meters)')
    plt.title(f'Connected Cycle Network Length – {scenario}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "connected_biketrack_avg.png"), dpi=300)
    plt.close()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith(" - Biketrack Connected Lengths")]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "connected_biketrack_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)
# Out:
# C:\Users\b8008458\AppData\Local\Temp\ipykernel_26180\988740930.py:17: RuntimeWarning: Mean of empty slice
#   scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
# [Warning] no_ltn_scenario missing Biketrack Demand LTN Priority Connected Lengths
# [Warning] no_ltn_scenario missing Biketrack Betweenness LTN Priority Connected Lengths

# %%
### missing random runs????

scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list):
            # Check if it's list of numbers
            if all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
                scenario_list_data[scenario][key].append(val)
            # Or list of lists of numbers
            elif all(isinstance(v, list) and all(isinstance(x, (int, float, np.number)) for x in v if x is not None) for v in val if v is not None):
                scenario_list_data[scenario][key].append(val)

# get means
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        # If nested list detected, flatten one level
        if len(lists) > 0 and isinstance(lists[0], list) and len(lists[0]) > 0 and isinstance(lists[0][0], list):
            flat = []
            for sublist in lists:
                flat.extend(sublist)
            lists = flat
        max_len = max(len(lst) for lst in lists)
        arr = np.full((len(lists), max_len), np.nan)
        for i, lst in enumerate(lists):
            arr[i, :len(lst)] = lst
        scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict

# Define plotting style
growth_orders = [("Betweenness Growth - Connected Biketrack Deviation from Random", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Connected Biketrack Deviation from Random", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Connected Biketrack Deviation from Random", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Connected Biketrack Deviation from Random", '-', 'purple', 'Betweenness LTN Priority Growth'),
    ("Connected Biketrack - Mean Deviation from Random", '--', 'blue', 'Random Growth (mean)')]

# Plot and save per scenario
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))

    # Plot each individual random run deviation series (list of lists)
    random_runs_all = overall.get("Connected Biketrack - Random Deviations (All Runs)", [])
    if len(random_runs_all) > 0:
        # Check if it's list of lists (nested)
        if isinstance(random_runs_all[0], (list, np.ndarray)):
            for run_dev in random_runs_all:
                plt.plot(run_dev, color='lightgray', linewidth=1, alpha=0.4)
        else:
            # It's a flat list of floats — plot it as one line
            plt.plot(random_runs_all, color='lightgray', linewidth=1, alpha=0.4)

    # Strategy deviations and mean
    for key, linestyle, color, label in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel("Investment Iteration")
    plt.ylabel("Deviation from Random Growth Baseline (meters)")
    plt.title(f"Biketrack Connected Deviation from Random – {scenario}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "connected_biketrack_deviation_avg.png"), dpi=300)
    plt.close()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders]
    if "Connected Biketrack - Random Deviations (All Runs)" in overall:
        included.append("Connected Biketrack - Random Deviations (All Runs)")
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "connected_biketrack_deviation_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)
# Out:
# C:\Users\b8008458\AppData\Local\Temp\ipykernel_26180\60257179.py:28: RuntimeWarning: Mean of empty slice
#   scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
# [Warning] no_ltn_scenario missing Demand LTN Priority Growth - Connected Biketrack Deviation from Random
# [Warning] no_ltn_scenario missing Betweenness LTN Priority Growth - Connected Biketrack Deviation from Random

# %%
# # distance gained
# # Plot just the bike track connected lengths 
# plt.figure(figsize=(10, 6))
# plt.plot(
#     range(1, len(overall_results['biketrack_lengths']) + 1),
#     overall_results['biketrack_lengths'],
#     '--', color='orange', label="Betweenness"
# )
# plt.plot(
#     range(1, len(overall_results['biketrack_random_lengths']) + 1),
#     overall_results['biketrack_random_lengths'],
#     '-', color='blue', label="Random"
# )

# plt.plot(
#     range(1, len(overall_results['biketrack_demand_lengths']) + 1),
#     overall_results['biketrack_demand_lengths'],
#     '-.', color='red', label="Demand"
# )

# plt.xlabel("Iteration")
# plt.ylabel("Additional Cycle Infrastructure Connected Length (meters)")
# plt.title("Additional Cycle Infrastructure Connected per Iteration")
# plt.legend()
# plt.grid(True, alpha=0.3)
# plt.tight_layout()
# output_path = overall_results_path +  "/additional_cyclenet_connected_avg.png"
# plt.savefig(output_path, dpi=300)
# plt.show()

# %% [markdown]
# # Connected Components

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and any(isinstance(v, (int, float, np.number)) for v in val):
            scenario_list_data[scenario][key].append([
                v if isinstance(v, (int, float, np.number)) else np.nan for v in val
            ])

# Compute mean across locations
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        max_len = max(len(lst) for lst in lists)
        arr = np.full((len(lists), max_len), np.nan)
        for i, lst in enumerate(lists):
            arr[i, :len(lst)] = lst
        scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict

growth_orders = [("Random Growth (mean) - LCC Length", '--', 'blue', 'Random Growth (mean)'),
    ("Betweenness Growth - LCC Length", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - LCC Length", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - LCC Length", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - LCC Length", '-', 'purple', 'Betweenness LTN Priority Growth')]

# Plot and save
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))

    # Plot random runs (up to 100)
    for i in range(1, 100):
        key = f"Random Run {i} - LCC Length"
        if key in overall:
            plt.plot(overall[key], color='lightgray', linewidth=1, alpha=0.4)
        else:
            break

    # Plot defined strategy lines
    for key, linestyle, color, label in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel('Investment Iteration')
    plt.ylabel('LCC Length (meters)')
    plt.title(f'Largest Connected Component Length – {scenario}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "lcc_length_avg.png"), dpi=300)
    plt.close()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders]
    included += [f"Random Run {i} - LCC Length" for i in range(1, 100) if f"Random Run {i} - LCC Length" in overall]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "lcc_length_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)
# Out:
# C:\Users\b8008458\AppData\Local\Temp\ipykernel_26180\2430067654.py:19: RuntimeWarning: Mean of empty slice
#   scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
# [Warning] no_ltn_scenario missing Demand LTN Priority Growth - LCC Length
# [Warning] no_ltn_scenario missing Betweenness LTN Priority Growth - LCC Length

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            scenario_list_data[scenario][key].append(val)

# Compute means across locations
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        max_len = max(len(lst) for lst in lists)
        arr = np.full((len(lists), max_len), np.nan)
        for i, lst in enumerate(lists):
            arr[i, :len(lst)] = lst
        scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict

# Define strategy line styles
growth_orders = [
    ("Betweenness Growth - LCC Length Deviation from Random", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - LCC Length Deviation from Random", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - LCC Length Deviation from Random", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - LCC Length Deviation from Random", '-', 'purple', 'Betweenness LTN Priority Growth')
]

# Plot
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))

    # Random run deviations
    for i in range(1, 100):
        key = f"Random Run {i} - LCC Length Deviation from Random"
        if key in overall:
            plt.plot(overall[key], color='lightgray', linewidth=1, alpha=0.4)
        else:
            break

    # Plot horizontal 0 baseline for mean random
    plt.axhline(0, color='blue', linestyle='--', linewidth=2, label='Random Growth (mean)')

    # Plot strategy lines
    for key, linestyle, color, label in growth_orders:
        if scenario == "no_ltn_scenario" and "LTN" in key:
            continue
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel("Investment Iteration")
    plt.ylabel("Deviation from Random Growth Baseline (meters)")
    plt.title(f"LCC Length Deviation from Random – {scenario}")
    plt.legend(loc='upper right')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "lcc_length_deviation_avg.png"), dpi=300)
    plt.show()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders]
    included += [f"Random Run {i} - LCC Length Deviation from Random" for i in range(1, 100) if f"Random Run {i} - LCC Length Deviation from Random" in overall]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "lcc_length_deviation_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)
# Out:
# C:\Users\b8008458\AppData\Local\Temp\ipykernel_26180\457691374.py:17: RuntimeWarning: Mean of empty slice
#   scenario_dict[key] = np.nanmean(arr, axis=0).tolist()

# %%
# # Plot LCC lengths
# plt.figure(figsize=(10, 6))
# plt.plot(
#     overall_results['lcc_lengths_GTs'], 
#     '--', color='orange', label='Ordered Growth'
# )
# plt.plot(
#     overall_results['lcc_lengths_GTs_random'], 
#     '-', color='blue', label='Random Growth'
# )

# plt.plot(
#     overall_results['lcc_lengths_GTs_demand'],
#     '-.', color='red', label='Demand Growth'
# )
# plt.xlabel('Investment Iteration')
# plt.ylabel('Length (meters)')
# plt.title('Size of Largest Connected Component per Iteration')
# plt.legend()
# plt.grid(True, alpha=0.3)
# plt.tight_layout()
# output_path = overall_results_path + "/size_of_lcc_avg.png"
# plt.savefig(output_path, dpi=300)
# plt.show()

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            scenario_list_data[scenario][key].append(val)

# Compute mean across locations
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        max_len = max(len(lst) for lst in lists)
        arr = np.full((len(lists), max_len), np.nan)
        for i, lst in enumerate(lists):
            arr[i, :len(lst)] = lst
        scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict

# Define plotting styles
growth_orders = [
    ("Random Growth (mean) - Composite LCC Length", '--', 'blue', 'Random Growth (mean)'),
    ("Betweenness Growth - Composite LCC Length", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Composite LCC Length", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Composite LCC Length", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Composite LCC Length", '-', 'purple', 'Betweenness LTN Priority Growth'),
]

# Plot per scenario
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))

    # Plot random runs
    for i in range(1, 100):
        key = f"Random Run {i} - Composite LCC Length"
        if key in overall:
            plt.plot(overall[key], color='lightgray', linewidth=1, alpha=0.4)
        else:
            break

    # Plot defined strategy lines
    for key, linestyle, color, label in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel("Investment Iteration")
    plt.ylabel("Composite LCC Length (meters)")
    plt.title(f"Composite LCC Length – {scenario}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    os.makedirs(fp, exist_ok=True)
    plt.savefig(os.path.join(fp, "composite_lcc_length_avg.png"), dpi=300)
    plt.show()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders] + \
               [f"Random Run {i} - Composite LCC Length" for i in range(1, 100) if f"Random Run {i} - Composite LCC Length" in overall]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "composite_lcc_length_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)
# Out:
# C:\Users\b8008458\AppData\Local\Temp\ipykernel_26180\2610225951.py:17: RuntimeWarning: Mean of empty slice
#   scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
# [Warning] no_ltn_scenario missing Demand LTN Priority Growth - Composite LCC Length
# [Warning] no_ltn_scenario missing Betweenness LTN Priority Growth - Composite LCC Length

# %%
# # LCC including addtional cycle network
# plt.figure(figsize=(10, 6))
# plt.plot(
#     overall_results['composite_lcc_GTs'],
#     '-', color='orange',
#     label='Betweenness Growth'
# )
# plt.plot(
#     overall_results['composite_lcc_GTs_random'],
#     '--', color='blue',
#     label='Random Growth'
# )
# plt.plot(
#     overall_results['composite_lcc_GTs_demand'],
#     '-.', color='red',
#     label='Demand Growth'
# )

# plt.title('Largest Connected Component (Including addtional connected bike network)')
# plt.xlabel('Investment Iteration')
# plt.ylabel('Total Length (meters)')
# plt.grid(True, alpha=0.3)
# plt.legend()
# plt.tight_layout()
# output_path = overall_results_path + "/lengthof_lcc_inc_cyclenet_avg.png"
# plt.savefig(output_path, dpi=300)
# plt.show()

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            scenario_list_data[scenario][key].append(val)

# Compute mean across locations
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        max_len = max(len(lst) for lst in lists)
        arr = np.full((len(lists), max_len), np.nan)
        for i, lst in enumerate(lists):
            arr[i, :len(lst)] = lst
        scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict

# Define strategy lines
growth_orders = [
    ("Betweenness Growth - Composite LCC Length Deviation from Random", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Composite LCC Length Deviation from Random", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Composite LCC Length Deviation from Random", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Composite LCC Length Deviation from Random", '-', 'purple', 'Betweenness LTN Priority Growth'),
]

# Plot per scenario
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))

    # Plot all individual random run deviations
    for i in range(1, 100):
        key = f"Random Run {i} - Composite LCC Length Deviation from Random"
        if key in overall:
            plt.plot(overall[key], color='lightgray', linewidth=1, alpha=0.4)
        else:
            break

    # Plot 0-axis line for random mean baseline
    plt.axhline(0, color='blue', linestyle='--', linewidth=2, label="Random Growth (mean)")

    # Plot strategy deviation lines
    for key, linestyle, color, label in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel("Investment Iteration")
    plt.ylabel("Deviation from Random Growth Baseline (meters)")
    plt.title(f"Composite LCC Deviation from Random – {scenario}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    os.makedirs(fp, exist_ok=True)
    plt.savefig(os.path.join(fp, "composite_lcc_length_deviation_avg.png"), dpi=300)
    plt.close()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders] + \
               [f"Random Run {i} - Composite LCC Length Deviation from Random" for i in range(1, 100) if f"Random Run {i} - Composite LCC Length Deviation from Random" in overall]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "composite_lcc_length_deviation_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)
# Out:
# C:\Users\b8008458\AppData\Local\Temp\ipykernel_26180\929869411.py:17: RuntimeWarning: Mean of empty slice
#   scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
# [Warning] no_ltn_scenario missing Demand LTN Priority Growth - Composite LCC Length Deviation from Random
# [Warning] no_ltn_scenario missing Betweenness LTN Priority Growth - Composite LCC Length Deviation from Random

# %%
# plt.figure(figsize=(10, 6))
# plt.plot(
#     range(1, len(overall_results['lcc_lengths_GTs']) + 1), 
#     overall_results['lcc_lengths_GTs'], 
#     linestyle='-', color='orange',  
#     label="Betweenness growth"
# )
# plt.plot(
#     range(1, len(overall_results['lcc_lengths_GTs_random']) + 1), 
#     overall_results['lcc_lengths_GTs_random'], 
#     linestyle='--', color='blue', 
#     label="Random growth"
# )
# plt.plot(
#     range(1, len(overall_results['lcc_lengths_GTs_demand']) + 1), 
#     overall_results['lcc_lengths_GTs_demand'], 
#     linestyle='-.', color='red', 
#     label="Demand growth"
# )
# plt.xlabel("Graph Index")
# plt.ylabel("Largest Connected Component Length (meters)")
# plt.title("Largest Connected Component Length")
# plt.legend()
# plt.grid(True, alpha=0.3)
# plt.tight_layout()
# output_path = overall_results_path + "/lcc_length_avg.png"
# plt.savefig(output_path, dpi=300)
# plt.show()

# %% [markdown]
# Disconnected Components

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            scenario_list_data[scenario][key].append(val)

# Compute mean across locations
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        max_len = max(len(lst) for lst in lists)
        arr = np.full((len(lists), max_len), np.nan)
        for i, lst in enumerate(lists):
            arr[i, :len(lst)] = lst
        scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict

# Define strategy plotting order
growth_orders = [
    ("Random Growth (mean) - Num Components", '--', 'blue', 'Random Growth (mean)'),
    ("Betweenness Growth - Num Components", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Num Components", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Num Components", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Num Components", '-', 'purple', 'Betweenness LTN Priority Growth')]

# Plot per scenario
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))

    # Plot all individual random runs
    for key in overall:
        if key.startswith("Random Run") and key.endswith(" - Num Components"):
            plt.plot(overall[key], color='lightgray', linewidth=1, alpha=0.4)

    # Plot strategy lines
    for key, linestyle, color, label in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel("Investment Iteration")
    plt.ylabel("Number of Components")
    plt.title(f"Number of Components – {scenario}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save figure
    fp = PATH["plots_overall_results"][scenario]
    os.makedirs(fp, exist_ok=True)
    plt.savefig(os.path.join(fp, "num_components_avg.png"), dpi=300)
    plt.close()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith(" - Num Components")]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "num_components_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)
# Out:
# C:\Users\b8008458\AppData\Local\Temp\ipykernel_26180\172037954.py:17: RuntimeWarning: Mean of empty slice
#   scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
# [Warning] no_ltn_scenario missing Demand LTN Priority Growth - Num Components
# [Warning] no_ltn_scenario missing Betweenness LTN Priority Growth - Num Components

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            scenario_list_data[scenario][key].append(val)

# Compute average per key per scenario
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        max_len = max(len(lst) for lst in lists)
        arr = np.full((len(lists), max_len), np.nan)
        for i, lst in enumerate(lists):
            arr[i, :len(lst)] = lst
        scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict


growth_orders = [
    ("Betweenness Growth - Num Components Deviation from Random", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Num Components Deviation from Random", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Num Components Deviation from Random", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Num Components Deviation from Random", '-', 'purple', 'Betweenness LTN Priority Growth')]

# Plot per scenario
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))

    # Plot individual random run deviations
    for key in overall:
        if key.startswith("Random Run") and key.endswith(" - Num Components Deviation from Random"):
            plt.plot(overall[key], color='lightgray', linewidth=1, alpha=0.4)

    # Plot 0 deviation baseline
    plt.axhline(0, color='blue', linestyle='--', linewidth=2, label='Random Growth (mean)')

    # Plot strategies
    for key, linestyle, color, label in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel("Investment Iteration")
    plt.ylabel("Deviation from Random Growth Baseline (num components)")
    plt.title(f"Deviation in Number of Components from Random – {scenario}")
    plt.legend(loc="upper right")
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    os.makedirs(fp, exist_ok=True)
    plt.savefig(os.path.join(fp, "num_components_deviation_avg.png"), dpi=300)
    plt.close()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith(" - Num Components Deviation from Random")]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "num_components_deviation_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)
# Out:
# C:\Users\b8008458\AppData\Local\Temp\ipykernel_26180\1112705797.py:17: RuntimeWarning: Mean of empty slice
#   scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
# [Warning] no_ltn_scenario missing Demand LTN Priority Growth - Num Components Deviation from Random
# [Warning] no_ltn_scenario missing Betweenness LTN Priority Growth - Num Components Deviation from Random

# %% [markdown]
# # Coverage

# %%
# Plotting - Area (km²)
plt.figure(figsize=(10, 6))
plt.plot(
    overall_results['buffer_areas'], 
    color='orange', 
    linestyle='-', 
    label='Betweenness Growth'
)
plt.plot(
    overall_results['random_buffer_areas'], 
    color='blue', 
    linestyle='--', 
    label='Random Growth'
)
plt.plot(
    overall_results['demand_buffer_areas'], 
    color='red', 
    linestyle='-.', 
    label='Demand Growth'
)
plt.xlabel('Iteration')
plt.ylabel('Area (km²)')
plt.title('Total Area Coverage')
plt.legend()
plt.tight_layout()
plt.grid(True, alpha=0.3)
output_path = overall_results_path + "/area_coverage_km2_avg.png"
plt.savefig(output_path, dpi=300)

plt.show()

# %%
# Plotting - Percentage Coverage
plt.figure(figsize=(10, 6))
plt.plot(
    overall_results['buffer_percentages'], 
    color='orange', 
    linestyle='-', 
    label='Betweeness Growth'
)
plt.plot(
    overall_results['random_buffer_percentages'], 
    color='blue', 
    linestyle='--', 
    label='Random Growth'
)
plt.plot(
    overall_results['demand_buffer_percentages'], 
    color='red', 
    linestyle='-.', 
    label='Demand Growth'
)
plt.xlabel('Iteration')
plt.ylabel('Coverage (%)')
plt.title('Percentage of Area Covered')
plt.legend()
plt.tight_layout()
plt.grid(True, alpha=0.3)
output_path = overall_results_path + "/boundary_cov_percentage_avg.png"
plt.savefig(output_path, dpi=300)

plt.show()

# %%
# Plot: Network Length within Buffers
plt.figure(figsize=(10, 6))
plt.plot(overall_results['street_cov_lengths'], color='orange', linestyle='-', label='Betweenness Growth')
plt.plot(overall_results['random_street_cov_lengths'], color='blue', linestyle='--', label='Random Growth')
plt.plot(overall_results['demand_street_cov_lengths'], color='red', linestyle='-.', label='Demand Growth')
plt.xlabel('Iteration')
plt.ylabel('Street Network Length (m)')
plt.title('Street Network Length within 350m of Cycling Network')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
output_path = overall_results_path + "/streets_within_cyclenet_avg.png"
plt.savefig(output_path, dpi=300)

plt.show()

# %%
# percentage of streets
plt.figure(figsize=(10, 6))
plt.plot(overall_results['street_cov_percentages'], color='orange', linestyle='-', label='Betweenness Growth')
plt.plot(overall_results['random_street_cov_percentages'], color='blue', linestyle='--', label='Random Growth')
plt.plot(overall_results['demand_street_cov_percentages'], color='red', linestyle='-.', label='Demand Growth')
plt.xlabel('Iteration')
plt.ylabel('Coverage (%)')
plt.title('Percentage of Total Network within Buffers')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
output_path = overall_results_path + "/percentage_within_cyclenet_avg.png"
plt.savefig(output_path, dpi=300)

plt.show()

# %%
# seed points
plt.figure(figsize=(10, 6))
x_vals = range(1, len(overall_results['points_covered_GT']) + 1)

plt.plot(
    x_vals,
    overall_results['points_covered_GT'],
    color='orange',
    linestyle='-',
    label='Betweenness Growth'
)
plt.plot(
    x_vals,
    overall_results['points_covered_random'],
    color='blue',
    linestyle='--',
    label='Random Growth'
)
plt.plot(
    x_vals,
    overall_results['points_covered_demand'],
    color='red',
    linestyle='-.',
    label='Demand-based Growth'
)

plt.xlabel('Growth Iteration')
plt.ylabel('Number of Points Covered')
plt.title('Seed Points Covered by Cycle Network')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
output_path = overall_results_path +  "/seed_point_coverage_avg.png"
plt.savefig(output_path, dpi=300)

plt.show()

# %%
# ltns
plt.figure(figsize=(10, 6))
x_vals = range(1, len(overall_results['ltn_points_covered_GT']) + 1)

plt.plot(
    x_vals,
    overall_results['ltn_points_covered_GT'],
    color='orange',
    linestyle='-',
    label='Betweenness Growth'
)
plt.plot(
    x_vals,
    overall_results['ltn_points_covered_random'],
    color='blue',
    linestyle='--',
    label='Random Growth'
)
plt.plot(
    x_vals,
    overall_results['ltn_points_covered_demand'],
    color='red',
    linestyle='-.',
    label='Demand-based Growth'
)

plt.xlabel('Growth Iteration')
plt.ylabel('Number of LTN Points Covered')
plt.title('LTNs Covered by Cycle Network')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
output_path = overall_results_path + "/ltns_coverage_avg.png"
plt.savefig(output_path, dpi=300)

plt.show()

# %%
# neighbourhoods
plt.figure(figsize=(10, 6))
x_vals = range(1, len(overall_results['neighborhood_points_covered_GT']) + 1)

plt.plot(
    x_vals,
    overall_results['neighborhood_points_covered_GT'],
    color='orange',
    linestyle='-',
    label='Betweenness Growth'
)
plt.plot(
    x_vals,
    overall_results['neighborhood_points_covered_random'],
    color='blue',
    linestyle='--',
    label='Random Growth'
)
plt.plot(
    x_vals,
    overall_results['neighborhood_points_covered_demand'],
    color='red',
    linestyle='-.',
    label='Demand-based Growth'
)

plt.xlabel('Growth Iteration')
plt.ylabel('Neighbourhoods Covered')
plt.title('Neighbourhoods Covered by Cycle Network')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
output_path = overall_results_path + "/neighbourhoods_coverage_avg.png"
plt.savefig(output_path, dpi=300)

plt.show()

# %% [markdown]
# # Overlap

# %%
# percentage of streets
plt.figure(figsize=(10, 6))
plt.plot(overall_results['overlap_size_percent_GTs'], color='orange', linestyle='-', label='Betweenness: Edge %')
plt.plot(overall_results['overlap_size_percent_random'], color='blue', linestyle='--',  label='Random: Edge %')
plt.plot(overall_results['overlap_size_percent_demand'], color='red', linestyle='-.',  label='Demand: Edge %')
plt.xlabel('Iteration')
plt.ylabel('Overlap (%)')
plt.title('Percentage Overlap with Existing Infrastructure')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
output_path = overall_results_path + "/percentage_overlap_cyclenet_avg.png"
plt.savefig(output_path, dpi=300)

plt.show()

# %%
# overlap edge count
plt.figure(figsize=(10, 6))
plt.plot(overall_results['overlap_edges_GTs'], color='orange', linestyle='-',  label='Betweenness')
plt.plot(overall_results['overlap_edges_random'], color='blue', linestyle='--', label='Random')
plt.plot(overall_results['overlap_edges_demand'], color='red', linestyle='-.',  label='Demand')
plt.xlabel('Iteration')
plt.ylabel('Edge Count')
plt.title('Overlap with Existing Infrastructure')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
output_path = overall_results_path + "/edge_count_overlap_cyclenet_avg.png"
plt.savefig(output_path, dpi=300)

plt.show()

# %%
# Overlap length
plt.figure(figsize=(10, 6))
plt.plot(overall_results['overlap_length_GTs'], color='orange', linestyle='-',  label='Betweenness')
plt.plot(overall_results['overlap_length_random'], color='blue', linestyle='--',  label='Random')
plt.plot(overall_results['overlap_length_demand'], color='red', linestyle='-.',  label='Demand')
plt.xlabel('Iteration')
plt.ylabel('Edge Count')
plt.title('Total Length of Overlapping Segments')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
output_path = overall_results_path + "/length_overlap_cyclenet_avg.png"
plt.savefig(output_path, dpi=300)

plt.show()

# %%
def plot_comparison(overall_results):
    fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(10, 16))

    # 1. Percentage Overlap
    ax1.plot(overall_results['overlap_size_percent_GTs'], color='orange', linestyle='-', label='Betweenness: Edge %')
    ax1.plot(overall_results['overlap_size_percent_random'], color='blue', linestyle='--',  label='Random: Edge %')
    ax1.plot(overall_results['overlap_size_percent_demand'], color='red', linestyle='-.',  label='Demand: Edge %')

    ax1.plot(overall_results['overlap_length_percent_GTs'], color='orange', linestyle='-',  label='Betweenness: Length %')
    ax1.plot(overall_results['overlap_length_percent_random'], color='blue', linestyle='--', label='Random: Length %')
    ax1.plot(overall_results['overlap_length_percent_demand'], color='red', linestyle='-.', label='Demand: Length %')

    ax1.set_title('Percentage Overlap with Existing Infrastructure')
    ax1.set_ylabel('Overlap (%)')
    ax1.legend()
    ax1.grid(True, alpha=0.3)

    # 2. Overlapping Edge Count
    ax2.plot(overall_results['overlap_edges_GTs'], color='orange', linestyle='-',  label='Betweenness')
    ax2.plot(overall_results['overlap_edges_random'], color='blue', linestyle='--', label='Random')
    ax2.plot(overall_results['overlap_edges_demand'], color='red', linestyle='-.',  label='Demand')

    ax2.set_title('Overlapping Edge Count')
    ax2.set_ylabel('Edges')
    ax2.legend()
    ax2.grid(True, alpha=0.3)

    # 3. Overlapping Length
    ax3.plot(overall_results['overlap_length_GTs'], color='orange', linestyle='-',  label='Betweenness')
    ax3.plot(overall_results['overlap_length_random'], color='blue', linestyle='--',  label='Random')
    ax3.plot(overall_results['overlap_length_demand'], color='red', linestyle='-.',  label='Demand')

    ax3.set_title('Overlapping Length')
    ax3.set_ylabel('Length (m)')
    ax3.legend()
    ax3.grid(True, alpha=0.3)

    plt.xlabel('Growth Iteration')
    plt.tight_layout()
    output_path = overall_results_path + "/overlap_with_existing_avg.png"
    plt.savefig(output_path, dpi=300)

    plt.show()


plot_comparison(overall_results)

# %% [markdown]
# # Directness

# %%
plt.figure(figsize=(10, 6))
plt.plot(
    overall_results['directness'],
    linestyle='--', 
    color='orange', 
    label='Betweenness'
)
plt.plot(
    overall_results['directness_random'],
    linestyle='-', 
    color='blue', 
    label='Random'
)
plt.plot(
    overall_results['directness_demand'],
    linestyle='-.', 
    color='red', 
    label='Demand'
)

plt.xlabel('Iteration')
plt.ylabel('Directness (Euclidean / Network Distance)')
plt.title('Network Directness Comparison')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
output_path = overall_results_path + "/directness_avg.png"
plt.savefig(output_path, dpi=300)
plt.show()

# %% [markdown]
# # Effieciency

# %%
# global efficiency

plt.figure(figsize=(10, 6))
plt.plot(
    overall_results['efficiency'],
    linestyle='-', 
    color='orange',
    label='Betweenness'
)
plt.plot(
    overall_results['efficiency_random'],
    linestyle='--', 
    color='blue',
    label='Random'
)
plt.plot(
    overall_results['efficiency_demand'],
    linestyle='-.', 
    color='red',
    label='Demand'
)

plt.xlabel('Iteration', fontsize=12)
plt.ylabel('Global Efficiency', fontsize=12)
plt.title('Global Network Efficiency Comparison', fontsize=14)
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()

output_path = overall_results_path + "/global_eff_avg.png"
plt.savefig(output_path, dpi=300)
plt.show()
