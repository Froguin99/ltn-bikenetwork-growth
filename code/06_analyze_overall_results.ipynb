# %% [markdown]
# # Step 6 - Analysis of overall bicycle network results
# ## Project: Growing Urban Bicycle Networks with LTNs

# %% [markdown]
# This notebook takes the existing infrastructure, the results from Step 5 and calculates/analyzes a number of measures as an average across all the processed locations

# %%
# import libraries
from src import utils
PATH = utils.PATH # shortening the var name so that we don't have to change it below

# System
import os
import glob
import dill as pickle
from collections import defaultdict
import pprint
pp = pprint.PrettyPrinter(indent=4)
from tqdm.notebook import tqdm
from pathlib import Path
from collections import defaultdict
import yaml
import json
from pathlib import Path


# Math/Data
import numpy as np
import pandas as pd

# Plotting
import matplotlib.pyplot as plt
import textwrap
import matplotlib.pyplot as plt
from PIL import Image
import matplotlib.image as mpimg


# Geo
import osmnx as ox
ox.settings.log_file = True
ox.settings.requests_timeout = 300
ox.settings.logs_folder = PATH["logs"]
import geopandas as gpd

# %% [markdown]
# ## Preliminaries

# %% [markdown]
# ### Parameters

# %%
debug = False # If True, will produce plots and/or verbose output to double-check
# if not debug: # Only do this if sure the code is bug-free!
#     warnings.filterwarnings('ignore')
rerun_existing = True # If True, will re-run the costly analysis of existing infra even if files already exist.
rerun = True # If True, recompute the analysis. If false, just re-make the plots

# %%
params = yaml.load(
    open("../parameters/parameters.yml"), 
    Loader=yaml.FullLoader)
osmnxparameters = json.load(open("../parameters/osmnxparameters.json", "r"))
plotparam = json.load(open("../parameters/plotparam.json", "r"))
plotparam_analysis = json.load(open("../parameters/plotparam_analysis.json", "r"))

# %% [markdown]
# ### Network weighting by tags

# %%
tag_lts = json.load(open("../parameters/tag_lts.json", "r"))
distance_cost = json.load(open("../parameters/distance_cost.json", "r"))

# %% [markdown]
# ## Loading

# %% [markdown]
# ### Load Results

# %%
# Load all analysis JSONs
results_list = []
for fp in Path(PATH["results"]).rglob("*_analysis_results.json"):
    try:
        placeid = fp.parent.parent.name
        scenario = fp.parent.name
        with open(fp, "r") as f:
            data = json.load(f)
        data["placeid"] = placeid
        data["scenario"] = scenario
        results_list.append(data)
        print(f"Loaded {fp} with {len(data)} results")
    except Exception as e:
        print(f"Failed to load {fp}: {e}")

# Separate into list-based and scalar-based
list_data = defaultdict(list)
scalar_data = defaultdict(list)

for res in results_list:
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            list_data[key].append(val)
        elif isinstance(val, (int, float, np.number)):
            scalar_data[key].append(val)

# Compute aggregated means
overall_results = {}
for key, list_of_lists in list_data.items():
    max_len = max(len(lst) for lst in list_of_lists)
    padded = np.full((len(list_of_lists), max_len), np.nan)
    for i, lst in enumerate(list_of_lists):
        padded[i, :len(lst)] = lst
    overall_results[key] = np.nanmean(padded, axis=0).tolist()

for key, values in scalar_data.items():
    overall_results[key] = float(np.nanmean(values))

# %% [markdown]
# # Saving Setup

# %%
folders_to_make = {"plots_overall_results": os.path.join(PATH["plots"], "overall_results"), "overall_results": os.path.join(Path(PATH["plots"]).parent, "overall_results")}
for key, base_path in folders_to_make.items():
    os.makedirs(base_path, exist_ok=True)
    PATH[key] = {scenario: os.path.join(base_path, scenario) for scenario in params["scenarios"]}
    for path in PATH[key].values():
        os.makedirs(path, exist_ok=True)

# %%
# empty dict to store results
overall_results_per_scenario = defaultdict(dict)

# %% [markdown]
# # Make plot matrix

# %%
plots_root = Path(PATH["plots"])
chosen_scenario = "current_ltn_scenario"
valid_places = ["newcastle", "gateshead", "sunderland", "north_tyneside", "south_tyneside"]

plot_order = [ #"L_of_Investment", "abs_dev_from_random_length",
               "total_investment_cost", "abs_dev_from_random_investment_cost",
    "length_difference", "length_difference_deviation_from_random", "Investment_vs_Length",
    "additional_cyclenet_connected", "biketrack_connected__deviation_from_random", "size_of_lcc",
    "lcc_length_deviation_from_random", "size_of_composite_lcc", "composite_lcc_deviation_from_random",
    "num_components", "num_components_deviation_from_random", "street_coverage_m", "street_coverage_pct",
    #"seed_coverage_analysis", 
    "overlap_size_percent", "overlap_size_deviation_from_random",
    "directness", "global_eff", "local_eff", "avg_node_degree", "avg_node_degree_deviation_from_random",
    "allLengths", "TotalLengthsCycleNet"]

# rename to nicer names
column_titles = [# "Length Invested", "Length Invested (Deviation from Random)", 
"Investment Cost (Routed - Existing)", "Investment Cost (Deviation from Random, Routed - Existing)",
    "Length Differance", "Length Differance (Deviation from Random)", "Investment Cost Vs Length Cost", "Addtional Cycle Network Connected",
    "Addtional Cycle Network Connected (Deviation from Random)", "Length of LCC (New Infrastructure Only)", "Length of LCC (Deviation from Random, New Infrastructure Only)", 
    "LCC Length", "LCC Length (Deviation from Random)",
    "Number of Disconnected Components", "Number of Disconnected Components (Deviation from Random)", "Street Coverage (M)", "Street Coverage (% of streets)",
     # "Seed Point Coverage",
    "Overlap with Existing %", "Overlap with Existing % (Deviation from Random)", "Directness", "Global Eff.", "Local Eff.",
    "Node Degree", "Node Deg (Deviation from Random)", "All Lengths", "CycleNet Total"]

for scenario in params["scenarios"]:
    print(f"Making matrix plot for scenario: {scenario}")
    # Load image paths
    place_to_plots = {}
    for place in valid_places:
        scenario_path = plots_root / place / scenario
        if scenario_path.exists():
            all_pngs = list(scenario_path.glob("*.png"))
            name_map = {p.stem: p for p in all_pngs}
            place_to_plots[place] = name_map

    n_rows = len(plot_order)
    n_cols = len(valid_places)
    fig = plt.figure(figsize=(2.5 * (n_cols + 1), 1.8 * n_rows), constrained_layout=True)
    gs = fig.add_gridspec(n_rows, n_cols + 1, width_ratios=[1] + [1] * n_cols, wspace=0.05, hspace=0.01)

    for row_idx, (plot_key, title) in enumerate(zip(plot_order, column_titles)):
        wrapped_title = "\n".join(textwrap.wrap(title, width=15))
        # Row labels
        ax_label = fig.add_subplot(gs[row_idx, 0])
        ax_label.text(0.5, 0.5, wrapped_title, ha="center", va="center", fontsize=8)
        ax_label.axis("off")
        for col_idx, place in enumerate(valid_places):
            ax = fig.add_subplot(gs[row_idx, col_idx + 1])
            plot_dict = place_to_plots.get(place, {})
            matched_path = plot_dict.get(plot_key)
            if matched_path and matched_path.exists():
                img = mpimg.imread(str(matched_path))
                ax.imshow(img)
            else:
                ax.text(0.5, 0.5, "Missing", ha="center", va="center", fontsize=8)
            ax.axis("off")

            if row_idx == 0:
                ax.set_title(place.replace("_", " ").title(), fontsize=10)

    plt.suptitle(f"{scenario.replace('_', ' ').title()} - All Metrics", fontsize=14)
    plt.savefig(Path(PATH["plots"]) / "overall_results" / scenario / "scenario_matrix_plot.png", dpi=800)
    plt.close()

# %% [markdown]
# # Lengths

# %% [markdown]
# Cycle network lengths

# %%
keys_labels = [('total_network_length', 'Fully Connected'),('total_biketrack_length', 'Biketrack'),('total_biketrack_no_ltn_length', 'Biketrack (no LTN)')]
scenario_results = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, _ in keys_labels:
        if key in res:
            scenario_results[scenario][key].append(res[key])

# Loop through each scenario and make plots
for scenario, data in scenario_results.items():
    means = {k: np.nanmean(v) for k, v in data.items()}
    overall_results_per_scenario[scenario].update({k: float(v) if not np.isnan(v) else None for k, v in means.items()})
    labels = [label for _, label in keys_labels]
    values = [means.get(key, np.nan) for key, _ in keys_labels]

    # Plotting
    plt.figure(figsize=(10, 6))
    plt.bar(labels, values)
    plt.xlabel('Network Type')
    plt.ylabel('Total Length (meters)')
    plt.title(f'Cycle Network Lengths – {scenario}')
    plt.tight_layout()
    output_path = os.path.join(PATH["plots_overall_results"][scenario], "cycleLengths_avg.png")
    plt.savefig(output_path, dpi=300)
    plt.show()

    # Print Stats
    print(f"\nScenario: {scenario}")
    for label, key, val in zip(labels, [k for k, _ in keys_labels], values):
        print(f"{label}: {val:.2f} m")
    if 'length_difference' in data:
        print(f"Difference in total length: {np.nanmean(data['length_difference']):.2f} m")

# Save overall results to JSON per scenario
for scenario, data in overall_results_per_scenario.items():
    output_json = os.path.join(PATH["overall_results"][scenario], "overall_summary_results.json")
    with open(output_json, "w") as f:
        json.dump(data, f, indent=2)

# %% [markdown]
# All network lengths

# %%
keys_for_all_lengths = ['total_biketrack_length', 'total_biketrack_no_ltn_length', 'total_network_length', 'total_investment_length']
scenario_results_all = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key in keys_for_all_lengths:
        if key in res:
            scenario_results_all[scenario][key].append(res[key])

# Loop through each scenario and make plots
for scenario, data in scenario_results_all.items():
    means = {k: np.nanmean(v) for k, v in data.items()}
    biketrack = means.get('total_biketrack_length', np.nan)
    biketrack_no_ltn = means.get('total_biketrack_no_ltn_length', np.nan)
    ltn_only = abs(biketrack - biketrack_no_ltn)
    full_network = means.get('total_network_length', np.nan)
    investment = means.get('total_investment_length', np.nan)

    labels = ["Existing Cycle Infrastructure (Including LTNs)",
        "Existing Cycle Infrastructure (Excluding LTNs)",
        "LTNs",
        "Fully Connected Cycle Network",
        "Investment Distance"]
    values = [biketrack, biketrack_no_ltn, ltn_only, full_network, investment]
    colors = ['deepskyblue'] * len(labels)

    # Add to overall_results_per_scenario
    overall_results_per_scenario[scenario].update({
        'ltn_only_length': float(ltn_only) if not np.isnan(ltn_only) else None,
        'length_comparison_labels': labels,
        'length_comparison_values': [float(v) if not np.isnan(v) else None for v in values]})

    # Plotting
    plt.figure(figsize=(12, 6))
    plt.bar(labels, values, color=colors)
    plt.xticks(rotation=15, ha='right')
    plt.xlabel('Network Type')
    plt.ylabel('Total Length (meters)')
    plt.title(f'All Network Lengths – {scenario}')
    plt.grid(True, axis="y", alpha=0.3)
    plt.tight_layout()
    output_path = os.path.join(PATH["plots_overall_results"][scenario], "allLengths_avg.png")
    plt.savefig(output_path, dpi=300)
    plt.close()

    # Print Stats
    print(f"\n[allLengths] Scenario: {scenario}")
    print(f"Fully connected network: {full_network:.2f} m")
    print(f"Biketrack: {biketrack:.2f} m")
    print(f"Biketrack (no LTN): {biketrack_no_ltn:.2f} m")
    print(f"LTN-only length: {ltn_only:.2f} m")
    print(f"Investment distance: {investment:.2f} m")

# Save overall results to JSON per scenario
for scenario, data in overall_results_per_scenario.items():
    output_json = os.path.join(PATH["overall_results"][scenario], "overall_summary_results.json")
    with open(output_json, "w") as f:
        json.dump(data, f, indent=2)

# %% [markdown]
# Investment length

# %%
# how much budget is used per iteration
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items(): # only series 
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            scenario_list_data[scenario][key].append(val)

# find mean across all locations for each scenario 
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        # Apply normalisation only for scenarios with variable iteration counts
        if scenario in ["no_ltn_scenario", "more_ltn_scenario"]:
            # Normalise each location's series to 100 percentage points
            normalised_lists = utils.normalise_by_percentage(lists, target_points=100)
            # Now all series have same length, can take mean
            if normalised_lists:
                arr = np.array(normalised_lists)
                scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
            else:
                scenario_dict[key] = []
        else:
            max_len = max(len(lst) for lst in lists)
            arr = np.full((len(lists), max_len), np.nan)
            for i, lst in enumerate(lists):
                arr[i, :len(lst)] = lst
            scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict

# set up for plotting
growth_orders = [("Random Growth (mean) - Total Investment Length", '--', 'blue', 'Random Growth (mean)'),
    ("Betweenness Growth - Total Investment Length", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Total Investment Length", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Total Investment Length", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Total Investment Length", '-', 'purple', 'Betweenness LTN Priority Growth')]

# plot and save
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))
    # individual random runs
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith("Total Investment Length") and "Deviation from Random" not in key:
            plt.plot(series, color='lightgray', linewidth=1, alpha=0.4)
 
    for key, ls, c, lbl in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=ls, color=c, label=lbl)
        else:
            print(f"[Warning] {scenario} missing {key}")
    plt.xlabel('Investment Iteration')
    plt.ylabel('Total Investment Length (meters)')
    plt.title(f'Length of Invested Cycle Network – {scenario}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # save
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "loInvestment_avg.png"), dpi=300)
    plt.show()

    # JSON dump of results
    included = [k for (k, *_ ) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith("Total Investment Length") and "Deviation from Random" not in k]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "loInvestment_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %%
# # how much budget is used per iteration
# plt.figure(figsize=(10, 6))
# plt.plot(overall_results['total_lengths'], linestyle='-', color='orange', label='Betweeness Growth')
# plt.plot(overall_results['random_total_lengths'], linestyle='--', color='blue', label='Random Growth')
# plt.plot(overall_results['demand_total_lengths'], linestyle='-.', color='red', label='Demand Growth')
# plt.xlabel('Investment Iteration')
# plt.ylabel('Total Length (meters)')
# plt.title('Length of Invested Cycle Network')
# plt.legend()
# plt.grid(True, alpha=0.3)
# plt.tight_layout()

# output_path = overall_results_path + "/loInvestment_avg.png"
# plt.savefig(output_path, dpi=300)

# plt.show()

# %% [markdown]
# "Actual" investment length

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():  # only series
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            scenario_list_data[scenario][key].append(val)

# Compute mean across locations
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        # Apply normalisation only for scenarios with variable iteration counts
        if scenario in ["no_ltn_scenario", "more_ltn_scenario"]:
            # Normalise each location's series to 100 percentage points
            normalised_lists = utils.normalise_by_percentage(lists, target_points=100)
            # Now all series have same length, can take mean
            if normalised_lists:
                arr = np.array(normalised_lists)
                scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
            else:
                scenario_dict[key] = []
        else:
            max_len = max(len(lst) for lst in lists)
            arr = np.full((len(lists), max_len), np.nan)
            for i, lst in enumerate(lists):
                arr[i, :len(lst)] = lst
            scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict


growth_orders = [("Random Growth (mean) - Total Investment Length", '--', 'blue', 'Random Investment'),
    ("Betweenness Growth - Total Investment Length", '-', 'orange', 'Betweenness Investment'),
    ("Demand Growth - Total Investment Length", '-.', 'red', 'Demand Investment'),
    ("Demand LTN Priority Growth - Total Investment Length", ':', 'green', 'Demand LTN Priority Investment'),
    ("Betweenness LTN Priority Growth - Total Investment Length", '-', 'purple', 'Betweenness LTN Priority Investment')]

# plot and save
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))

    # Plot individual random runs
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith("Total Investment Length") and "Deviation from Random" not in key:
            plt.plot(series, color='lightgray', linewidth=1, alpha=0.4)

    # Plot defined strategy lines
    for key, linestyle, color, label in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel('Investment Iteration')
    plt.ylabel('Total Investment Length (meters)')
    plt.title(f'Total Investment Required – {scenario}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "RequiredloInvestment_avg.png"), dpi=300)
    plt.close()

    # Save JSON dump
    included = [k for (k, *_ ) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith("Total Investment Length") and "Deviation from Random" not in k]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "RequiredloInvestment_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():  # only series
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            scenario_list_data[scenario][key].append(val)

# Compute mean across locations
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        max_len = max(len(lst) for lst in lists)
        arr = np.full((len(lists), max_len), np.nan)
        for i, lst in enumerate(lists):
            arr[i, :len(lst)] = lst
        scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict

# Set plotting order
growth_orders = [("Random Growth (mean) - Deviation from Random - Total Investment Length", '--', 'blue', 'Random Growth (mean)'),
    ("Betweenness Growth - Deviation from Random - Total Investment Length", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Deviation from Random - Total Investment Length", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Deviation from Random - Total Investment Length", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Deviation from Random - Total Investment Length", '-', 'purple', 'Betweenness LTN Priority Growth')]

# Plot and save per scenario
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith("Deviation from Random - Total Investment Length"):
            plt.plot(series, color='lightgray', linewidth=1, alpha=0.4)
    for key, linestyle, color, label in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel('Investment Iteration')
    plt.ylabel('Deviation from Random Investment (meters)')
    plt.title(f'Deviation from Random - Total Investment Length – {scenario}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save figure
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "RequiredloInvestment_dev_from_random.png"), dpi=300)
    plt.close()

    # Save JSON of plotted data
    included = [k for (k, *_ ) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith("Deviation from Random - Total Investment Length")]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "RequiredloInvestment_dev_from_random.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %%
# # actual investment length
# plt.figure(figsize=(10, 6))
# plt.plot(overall_results['total_investment_lengths'],        '-',  color='orange', label='Betweeness Investment')
# plt.plot(overall_results['random_total_investment_lengths'], '--', color='blue',   label='Random Investment')
# plt.plot(overall_results['demand_total_investment_lengths'], '-.', color='red',    label='Demand Investment')
# plt.xlabel('Investment Iteration')
# plt.ylabel('Total Length (meters)')
# plt.title('Length of Investment Required')
# plt.legend()
# plt.grid(True, alpha=0.3)
# plt.tight_layout()

# output_path = overall_results_path + "/RequiredloInvestment_avg.png"
# plt.savefig(output_path, dpi=300)

# plt.show()

# %%
################################# Get rid?

# # both on one plot
# plt.figure(figsize=(10, 6))
# plt.plot(overall_results['investment_total_lengths'],        '-',  color='orange',    label='Betweenness (Invest)')
# plt.plot(overall_results['random_investment_total_lengths'], '--', color='blue',     label='Random (Invest)')
# plt.plot(overall_results['demand_investment_total_lengths'], '-.', color='red',      label='Demand (Invest)')
# plt.plot(overall_results['length_total_lengths'],            '-',  color='darkorange', alpha=0.7, label='Betweenness (Length)')
# plt.plot(overall_results['random_length_total_lengths'],     '--', color='darkblue',   alpha=0.7, label='Random (Length)')
# plt.plot(overall_results['demand_length_total_lengths'],     '-.', color='darkred',    alpha=0.7, label='Demand (Length)')

# plt.xlabel('Investment Iteration')
# plt.ylabel('Total Length (meters)')
# plt.title('Network size vs Investment required comparison')
# plt.legend()
# plt.grid(True, alpha=0.3)
# plt.tight_layout()

# output_path = overall_results_path + "/Required_vs_networksize_loInvestment.png"
# plt.savefig(output_path, dpi=300)
# plt.show()


# differance between total network size and investment required
# plt.figure(figsize=(10, 6))
# plt.plot(overall_results['length_differences'],         '-',  color='orange', label='Betweeness Growth')
# plt.plot(overall_results['random_length_differences'],  '--', color='blue',  label='Random Growth')
# plt.plot(overall_results['demand_length_differences'],  '-.', color='red',   label='Demand Growth')  # demand line
# plt.xlabel('Investment Iteration')
# plt.ylabel('Length Difference (meters)')
# plt.title('Difference between total network size and investment size required')
# plt.legend()
# plt.grid(True, alpha=0.3)
# plt.tight_layout()
# output_path = overall_results_path +  "/loInvestment_diff_avg.png"
# plt.savefig(output_path, dpi=300)

# plt.show()

# %% [markdown]
# Differance between network size and required investment

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            scenario_list_data[scenario][key].append(val)

# Compute mean across locations
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        # Apply normalisation only for scenarios with variable iteration counts
        if scenario in ["no_ltn_scenario", "more_ltn_scenario"]:
            # Normalise each location's series to 100 percentage points
            normalised_lists = utils.normalise_by_percentage(lists, target_points=100)
            # Now all series have same length, can take mean
            if normalised_lists:
                arr = np.array(normalised_lists)
                scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
            else:
                scenario_dict[key] = []
        else:
            max_len = max(len(lst) for lst in lists)
            arr = np.full((len(lists), max_len), np.nan)
            for i, lst in enumerate(lists):
                arr[i, :len(lst)] = lst
            scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict


growth_orders = [("Random Growth (mean) - Length Difference", '--', 'blue', 'Random Growth (mean)'),
    ("Betweenness Growth - Length Difference", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Length Difference", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Length Difference", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Length Difference", '-', 'purple', 'Betweenness LTN Priority Growth')]

# Plot and save
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith(" - Length Difference"):
            plt.plot(series, color='lightgray', linewidth=1, alpha=0.4)
    for key, linestyle, color, label in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel('Investment Iteration')
    plt.ylabel('Length Difference (meters)')
    plt.title(f'Length Difference Compared to Baseline – {scenario}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "length_difference_avg.png"), dpi=300)
    plt.close()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith(" - Length Difference")]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "length_difference_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %%
### missing length difference????

scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            if "Length Difference" in key:
                scenario_list_data[scenario][key].append(val)

# Compute mean across locations
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        max_len = max(len(lst) for lst in lists)
        arr = np.full((len(lists), max_len), np.nan)
        for i, lst in enumerate(lists):
            arr[i, :len(lst)] = lst
        scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict

# Compute random run and random mean deviations
# (notebook 05 saves raw Length Difference for random runs but not the deviation versions)
for scenario, scenario_dict in scenario_overall.items():
    random_mean = scenario_dict.get("Random Growth (mean) - Length Difference")
    if random_mean is None:
        print(f"[Warning] No random mean Length Difference for {scenario}")
        continue
    rand_arr = np.array(random_mean)
    for rkey in [k for k in scenario_dict if k.startswith("Random Run") and k.endswith(" - Length Difference")]:
        dev_key = rkey.replace(" - Length Difference", " - Deviation from Random Length Difference")
        r_arr = np.array(scenario_dict[rkey])
        n = min(len(r_arr), len(rand_arr))
        scenario_dict[dev_key] = (r_arr[:n] - rand_arr[:n]).tolist()
    # Random mean deviation is zero by definition, but plot it explicitly
    scenario_dict["Random Growth (mean) - Deviation from Random Length Difference"] = [0.0] * len(random_mean)

growth_orders = [
    ("Random Growth (mean) - Deviation from Random Length Difference", "--", "blue", "Random Growth (mean)"),
    ("Betweenness Growth - Deviation from Random Length Difference", "-", "orange", "Betweenness Growth"),
    ("Demand Growth - Deviation from Random Length Difference", "-.", "red", "Demand Growth"),
    ("Demand LTN Priority Growth - Deviation from Random Length Difference", ":", "green", "Demand LTN Priority Growth"),
    ("Betweenness LTN Priority Growth - Deviation from Random Length Difference", "-", "purple", "Betweenness LTN Priority Growth"),
]

# Plot and save
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))

    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith(" - Deviation from Random Length Difference"):
            plt.plot(series, color="lightgray", linewidth=1, alpha=0.4)

    for key, linestyle, color, label in growth_orders:
        if scenario == "no_ltn_scenario" and "LTN" in key:
            continue
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel("Investment Iteration")
    plt.ylabel("Deviation from Random (meters)")
    plt.title(f"Deviation from Random – Length Difference – {scenario}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "length_difference_absdev.png"), dpi=300)
    plt.close()

    included = [k for (k, *_) in growth_orders] +                [k for k in overall if k.startswith("Random Run") and "Deviation from Random Length Difference" in k]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "length_difference_absdev.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %%
# # investment cost vs physical network length

# plt.figure(figsize=(10, 6))
# plt.plot(
#     overall_results['lengths_list'], 
#     overall_results['investment_lengths_list'], 
#     '-', color='orange', label='Betweenness Growth'
# )
# plt.plot(
#     overall_results['random_lengths_list'], 
#     overall_results['random_investment_lengths_list'], 
#     '--', color='blue', label='Random Growth'
# )
# plt.plot(
#     overall_results['demand_lengths_list'], 
#     overall_results['demand_investment_lengths_list'], 
#     '-.', color='red', label='Demand Growth'
# )
# plt.xlabel('Total Length (meters)')
# plt.ylabel('Total Investment Length (meters)')
# plt.title('Investment Cost vs Physical Network Length')
# plt.legend()
# plt.grid(True, alpha=0.3)
# plt.tight_layout()
# output_path = overall_results_path + "/loInvestmentcost_vs_length_avg.png"
# plt.savefig(output_path, dpi=300)

# plt.show()

# %% [markdown]
# Distance gained

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            scenario_list_data[scenario][key].append(val)

# Compute mean across locations
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        # Apply normalisation only for scenarios with variable iteration counts
        if scenario in ["no_ltn_scenario", "more_ltn_scenario"]:
            # Normalise each location's series to 100 percentage points
            normalised_lists = utils.normalise_by_percentage(lists, target_points=100)
            # Now all series have same length, can take mean
            if normalised_lists:
                arr = np.array(normalised_lists)
                scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
            else:
                scenario_dict[key] = []
        else:
            max_len = max(len(lst) for lst in lists)
            arr = np.full((len(lists), max_len), np.nan)
            for i, lst in enumerate(lists):
                arr[i, :len(lst)] = lst
            scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict


growth_orders = [("Biketrack Random Mean - Connected Lengths", '--', 'blue', 'Random Growth (mean)'),
    ("Biketrack Connected Lengths", '-', 'orange', 'Betweenness Growth'),
    ("Biketrack Demand Connected Lengths", '-.', 'red', 'Demand Growth'),
    ("Biketrack Demand LTN Priority Connected Lengths", ':', 'green', 'Demand LTN Priority Growth'),
    ("Biketrack Betweenness LTN Priority Connected Lengths", '-', 'purple', 'Betweenness LTN Priority Growth')]

# Plot and save
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))

    # Plot random runs
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith(" - Biketrack Connected Lengths"):
            plt.plot(series, color='lightgray', linewidth=1, alpha=0.4)

    # Plot defined strategy lines
    for key, linestyle, color, label in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel('Investment Iteration')
    plt.ylabel('Biketrack Connected Length (meters)')
    plt.title(f'Connected Cycle Network Length – {scenario}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "connected_biketrack_avg.png"), dpi=300)
    plt.close()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith(" - Biketrack Connected Lengths")]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "connected_biketrack_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %%
# from results list print if we have random runs from connected biketrack devivation

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            if ("Biketrack" in key and "Connected" in key) or ("Connected Biketrack Deviation" in key):
                scenario_list_data[scenario][key].append(val)

# Compute means across locations
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        max_len = max(len(lst) for lst in lists)
        arr = np.full((len(lists), max_len), np.nan)
        for i, lst in enumerate(lists):
            arr[i, :len(lst)] = lst
        scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict

# Compute per-method deviations from the random mean connected length
# (notebook 05 saves the lengths but not these per-method deviation keys)
method_key_map = {
    "Betweenness Growth":              "Biketrack Connected Lengths",
    "Demand Growth":                   "Biketrack Demand Connected Lengths",
    "Demand LTN Priority Growth":      "Biketrack Demand LTN Priority Connected Lengths",
    "Betweenness LTN Priority Growth": "Biketrack Betweenness LTN Priority Connected Lengths",
}
for scenario, scenario_dict in scenario_overall.items():
    random_mean = scenario_dict.get("Biketrack Random Mean - Connected Lengths")
    if random_mean is None:
        print(f"[Warning] No random mean biketrack connected for {scenario}")
        continue
    rand_arr = np.array(random_mean)
    for method, src_key in method_key_map.items():
        dev_key = f"{method} - Connected Biketrack Deviation from Random"
        if src_key in scenario_dict:
            m_arr = np.array(scenario_dict[src_key])
            n = min(len(m_arr), len(rand_arr))
            scenario_dict[dev_key] = (m_arr[:n] - rand_arr[:n]).tolist()

growth_orders = [
    ("Betweenness Growth - Connected Biketrack Deviation from Random", "-", "orange", "Betweenness Growth"),
    ("Demand Growth - Connected Biketrack Deviation from Random", "-.", "red", "Demand Growth"),
    ("Demand LTN Priority Growth - Connected Biketrack Deviation from Random", ":", "green", "Demand LTN Priority Growth"),
    ("Betweenness LTN Priority Growth - Connected Biketrack Deviation from Random", "-", "purple", "Betweenness LTN Priority Growth"),
]

for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))

    # Individual random run deviations
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith(" - Connected Biketrack Deviation from Random"):
            plt.plot(series, color="lightgray", linewidth=1, alpha=0.4)

    # Random mean as zero baseline
    rand_mean_dev = overall.get("Random Growth (mean) - Connected Biketrack Deviation from Random")
    if rand_mean_dev is not None:
        plt.plot(rand_mean_dev, color="blue", linestyle="--", linewidth=2, label="Random Growth (mean)")
    else:
        plt.axhline(0, color="blue", linestyle="--", linewidth=2, label="Random Growth (mean)")

    for key, linestyle, color, label in growth_orders:
        if scenario == "no_ltn_scenario" and "LTN" in key:
            continue
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel("Investment Iteration")
    plt.ylabel("Deviation from Random Growth Baseline (meters)")
    plt.title(f"Biketrack Connected Deviation from Random – {scenario}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "connected_biketrack_deviation_avg.png"), dpi=300)
    plt.close()

    included = [k for (k, *_) in growth_orders] +                [k for k in overall if k.startswith("Random Run") and "Connected Biketrack Deviation" in k]
    if rand_mean_dev is not None:
        included.append("Random Growth (mean) - Connected Biketrack Deviation from Random")
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "connected_biketrack_deviation_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %% [markdown]
# # Connected Components

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and any(isinstance(v, (int, float, np.number)) for v in val):
            scenario_list_data[scenario][key].append([
                v if isinstance(v, (int, float, np.number)) else np.nan for v in val
            ])

# Compute mean across locations
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        # Apply normalisation only for scenarios with variable iteration counts
        if scenario in ["no_ltn_scenario", "more_ltn_scenario"]:
            # Normalise each location's series to 100 percentage points
            normalised_lists = utils.normalise_by_percentage(lists, target_points=100)
            # Now all series have same length, can take mean
            if normalised_lists:
                arr = np.array(normalised_lists)
                scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
            else:
                scenario_dict[key] = []
        else:
            max_len = max(len(lst) for lst in lists)
            arr = np.full((len(lists), max_len), np.nan)
            for i, lst in enumerate(lists):
                arr[i, :len(lst)] = lst
            scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict

growth_orders = [("Random Growth (mean) - LCC Length", '--', 'blue', 'Random Growth (mean)'),
    ("Betweenness Growth - LCC Length", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - LCC Length", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - LCC Length", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - LCC Length", '-', 'purple', 'Betweenness LTN Priority Growth')]

# Plot and save
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))

    # Plot random runs (up to 100)
    for i in range(1, 100):
        key = f"Random Run {i} - LCC Length"
        if key in overall:
            plt.plot(overall[key], color='lightgray', linewidth=1, alpha=0.4)
        else:
            break

    # Plot defined strategy lines
    for key, linestyle, color, label in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel('Investment Iteration')
    plt.ylabel('LCC Length (meters)')
    plt.title(f'Largest Connected Component Length – {scenario}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "lcc_length_avg.png"), dpi=300)
    plt.close()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders]
    included += [f"Random Run {i} - LCC Length" for i in range(1, 100) if f"Random Run {i} - LCC Length" in overall]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "lcc_length_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            scenario_list_data[scenario][key].append(val)

# Compute mean across locations
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        # Apply normalisation only for scenarios with variable iteration counts
        if scenario in ["no_ltn_scenario", "more_ltn_scenario"]:
            # Normalise each location's series to 100 percentage points
            normalised_lists = utils.normalise_by_percentage(lists, target_points=100)
            # Now all series have same length, can take mean
            if normalised_lists:
                arr = np.array(normalised_lists)
                scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
            else:
                scenario_dict[key] = []
        else:
            max_len = max(len(lst) for lst in lists)
            arr = np.full((len(lists), max_len), np.nan)
            for i, lst in enumerate(lists):
                arr[i, :len(lst)] = lst
            scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict


# Define plotting styles
growth_orders = [
    ("Random Growth (mean) - Composite LCC Length", '--', 'blue', 'Random Growth (mean)'),
    ("Betweenness Growth - Composite LCC Length", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Composite LCC Length", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Composite LCC Length", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Composite LCC Length", '-', 'purple', 'Betweenness LTN Priority Growth'),]

# Plot per scenario
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))

    # Plot random runs
    for i in range(1, 100):
        key = f"Random Run {i} - Composite LCC Length"
        if key in overall:
            plt.plot(overall[key], color='lightgray', linewidth=1, alpha=0.4)
        else:
            break

    # Plot defined strategy lines
    for key, linestyle, color, label in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel("Investment Iteration")
    plt.ylabel("Composite LCC Length (meters)")
    plt.title(f"Composite LCC Length – {scenario}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    os.makedirs(fp, exist_ok=True)
    plt.savefig(os.path.join(fp, "composite_lcc_length_avg.png"), dpi=300)
    plt.close()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders] + \
               [f"Random Run {i} - Composite LCC Length" for i in range(1, 100) if f"Random Run {i} - Composite LCC Length" in overall]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "composite_lcc_length_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            scenario_list_data[scenario][key].append(val)


scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        max_len = max(len(lst) for lst in lists)
        arr = np.full((len(lists), max_len), np.nan)
        for i, lst in enumerate(lists):
            arr[i, :len(lst)] = lst
        scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict


growth_orders = [("Betweenness Growth - Composite LCC Length Deviation from Random", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Composite LCC Length Deviation from Random", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Composite LCC Length Deviation from Random", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Composite LCC Length Deviation from Random", '-', 'purple', 'Betweenness LTN Priority Growth'),]

# Plot per scenario
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))
    for i in range(1, 100):
        key = f"Random Run {i} - Composite LCC Length Deviation from Random"
        if key in overall:
            plt.plot(overall[key], color='lightgray', linewidth=1, alpha=0.4)
        else:
            break
    plt.axhline(0, color='blue', linestyle='--', linewidth=2, label="Random Growth (mean)")

    # Plot strategy deviation lines
    for key, linestyle, color, label in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel("Investment Iteration")
    plt.ylabel("Deviation from Random Growth Baseline (meters)")
    plt.title(f"Composite LCC Deviation from Random – {scenario}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    os.makedirs(fp, exist_ok=True)
    plt.savefig(os.path.join(fp, "composite_lcc_length_deviation_avg.png"), dpi=300)
    plt.close()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders] + \
               [f"Random Run {i} - Composite LCC Length Deviation from Random" for i in range(1, 100) if f"Random Run {i} - Composite LCC Length Deviation from Random" in overall]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "composite_lcc_length_deviation_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %% [markdown]
# Disconnected Components

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            scenario_list_data[scenario][key].append(val)

# Compute mean across locations
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        # Apply normalisation only for scenarios with variable iteration counts
        if scenario in ["no_ltn_scenario", "more_ltn_scenario"]:
            # Normalise each location's series to 100 percentage points
            normalised_lists = utils.normalise_by_percentage(lists, target_points=100)
            # Now all series have same length, can take mean
            if normalised_lists:
                arr = np.array(normalised_lists)
                scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
            else:
                scenario_dict[key] = []
        else:
            max_len = max(len(lst) for lst in lists)
            arr = np.full((len(lists), max_len), np.nan)
            for i, lst in enumerate(lists):
                arr[i, :len(lst)] = lst
            scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict


growth_orders = [("Random Growth (mean) - Num Components", '--', 'blue', 'Random Growth (mean)'),
    ("Betweenness Growth - Num Components", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Num Components", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Num Components", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Num Components", '-', 'purple', 'Betweenness LTN Priority Growth')]

# Plot per scenario
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))
    # Plot all individual random runs
    for key in overall:
        if key.startswith("Random Run") and key.endswith(" - Num Components"):
            plt.plot(overall[key], color='lightgray', linewidth=1, alpha=0.4)

    for key, linestyle, color, label in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel("Investment Iteration")
    plt.ylabel("Number of Components")
    plt.title(f"Number of Components – {scenario}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save figure
    fp = PATH["plots_overall_results"][scenario]
    os.makedirs(fp, exist_ok=True)
    plt.savefig(os.path.join(fp, "num_components_avg.png"), dpi=300)
    plt.close()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith(" - Num Components")]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "num_components_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            scenario_list_data[scenario][key].append(val)

# Compute average per key per scenario
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        max_len = max(len(lst) for lst in lists)
        arr = np.full((len(lists), max_len), np.nan)
        for i, lst in enumerate(lists):
            arr[i, :len(lst)] = lst
        scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict


growth_orders = [("Betweenness Growth - Num Components Deviation from Random", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Num Components Deviation from Random", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Num Components Deviation from Random", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Num Components Deviation from Random", '-', 'purple', 'Betweenness LTN Priority Growth')]

# Plot per scenario
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))

    # Plot individual random run deviations
    for key in overall:
        if key.startswith("Random Run") and key.endswith(" - Num Components Deviation from Random"):
            plt.plot(overall[key], color='lightgray', linewidth=1, alpha=0.4)
    plt.axhline(0, color='blue', linestyle='--', linewidth=2, label='Random Growth (mean)')
    for key, linestyle, color, label in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel("Investment Iteration")
    plt.ylabel("Deviation from Random Growth Baseline (num components)")
    plt.title(f"Deviation in Number of Components from Random – {scenario}")
    plt.legend(loc="upper right")
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    os.makedirs(fp, exist_ok=True)
    plt.savefig(os.path.join(fp, "num_components_deviation_avg.png"), dpi=300)
    plt.close()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith(" - Num Components Deviation from Random")]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "num_components_deviation_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %% [markdown]
# # Coverage

# %%
# Coverage – Street Coverage Percentage
from collections import defaultdict
coverage_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            if key.endswith(" - Street Coverage %"):
                coverage_list_data[scenario][key].append(val)

# Compute mean series per scenario
coverage_overall = {}
for scenario, data in coverage_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        if scenario in ["no_ltn_scenario", "more_ltn_scenario"]:
            normalised = utils.normalise_by_percentage(lists, target_points=100)
            arr = np.array(normalised) if normalised else np.empty((0,0))
        else:
            max_len = max(len(lst) for lst in lists)
            arr = np.full((len(lists), max_len), np.nan)
            for i, lst in enumerate(lists):
                arr[i, :len(lst)] = lst
        scenario_dict[key] = np.nanmean(arr, axis=0).tolist()

    # Compute Random Growth (mean) if missing
    if "Random Growth (mean) - Street Coverage %" not in scenario_dict:
        random_keys = [k for k in scenario_dict if k.startswith("Random Run") and k.endswith(" - Street Coverage %")]
        random_arrays = [scenario_dict[k] for k in random_keys]
        if random_arrays:
            if scenario in ["no_ltn_scenario", "more_ltn_scenario"]:
                mean_series = np.nanmean(np.array(random_arrays), axis=0).tolist()
            else:
                max_len = max(len(a) for a in random_arrays)
                padded = np.full((len(random_arrays), max_len), np.nan)
                for i, a in enumerate(random_arrays):
                    padded[i, :len(a)] = a
                mean_series = np.nanmean(padded, axis=0).tolist()
            scenario_dict["Random Growth (mean) - Street Coverage %"] = mean_series

    coverage_overall[scenario] = scenario_dict

# Plotting
growth_orders = [
    ("Random Growth (mean) - Street Coverage %", '--', 'blue', 'Random Growth (mean)'),
    ("Betweenness Growth - Street Coverage %", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Street Coverage %", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Street Coverage %", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Street Coverage %", '-', 'purple', 'Betweenness LTN Priority Growth'),
]

for scenario in params["scenarios"]:
    overall = coverage_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))

    # grey lines for individual random runs
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith(" - Street Coverage %"):
            plt.plot(series, color='lightgray', linewidth=1, alpha=0.4)

    # strategy lines
    for key, ls, c, lbl in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=ls, color=c, label=lbl)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel("Growth Iteration")
    plt.ylabel("Street Coverage (%)")
    plt.title(f"Street Network Coverage Percentage – {scenario}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot & JSON
    fp_plot = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp_plot, "street_coverage_pct.png"), dpi=300)
    plt.show()

    summary_keys = [k for (k, *_) in growth_orders] + \
                   [k for k in overall if k.startswith("Random Run") and k.endswith(" - Street Coverage %")]
    summary = {k: overall[k] for k in summary_keys if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "street_coverage_pct.json"), "w") as f:
        json.dump(summary, f, indent=2)
# Coverage – Street Coverage Percentage
from collections import defaultdict
coverage_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            if key.endswith(" - Street Coverage %"):
                coverage_list_data[scenario][key].append(val)

# Compute mean series per scenario
coverage_overall = {}
for scenario, data in coverage_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        if scenario in ["no_ltn_scenario", "more_ltn_scenario"]:
            normalised = utils.normalise_by_percentage(lists, target_points=100)
            arr = np.array(normalised) if normalised else np.empty((0,0))
        else:
            max_len = max(len(lst) for lst in lists)
            arr = np.full((len(lists), max_len), np.nan)
            for i, lst in enumerate(lists):
                arr[i, :len(lst)] = lst
        scenario_dict[key] = np.nanmean(arr, axis=0).tolist()

    # Compute Random Growth (mean) if missing
    if "Random Growth (mean) - Street Coverage %" not in scenario_dict:
        random_keys = [k for k in scenario_dict if k.startswith("Random Run") and k.endswith(" - Street Coverage %")]
        random_arrays = [scenario_dict[k] for k in random_keys]
        if random_arrays:
            if scenario in ["no_ltn_scenario", "more_ltn_scenario"]:
                mean_series = np.nanmean(np.array(random_arrays), axis=0).tolist()
            else:
                max_len = max(len(a) for a in random_arrays)
                padded = np.full((len(random_arrays), max_len), np.nan)
                for i, a in enumerate(random_arrays):
                    padded[i, :len(a)] = a
                mean_series = np.nanmean(padded, axis=0).tolist()
            scenario_dict["Random Growth (mean) - Street Coverage %"] = mean_series

    coverage_overall[scenario] = scenario_dict

# Plotting
growth_orders = [
    ("Random Growth (mean) - Street Coverage %", '--', 'blue', 'Random Growth (mean)'),
    ("Betweenness Growth - Street Coverage %", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Street Coverage %", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Street Coverage %", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Street Coverage %", '-', 'purple', 'Betweenness LTN Priority Growth'),]

for scenario in params["scenarios"]:
    overall = coverage_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))

    # grey lines for individual random runs
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith(" - Street Coverage %"):
            plt.plot(series, color='lightgray', linewidth=1, alpha=0.4)

    # strategy lines
    for key, ls, c, lbl in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=ls, color=c, label=lbl)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel("Growth Iteration")
    plt.ylabel("Street Coverage (%)")
    plt.title(f"Street Network Coverage Percentage – {scenario}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot & JSON
    fp_plot = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp_plot, "street_coverage_pct.png"), dpi=300)
    plt.show()

    summary_keys = [k for (k, *_) in growth_orders] + \
                   [k for k in overall if k.startswith("Random Run") and k.endswith(" - Street Coverage %")]
    summary = {k: overall[k] for k in summary_keys if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "street_coverage_pct.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            scenario_list_data[scenario][key].append(val)

# Compute average per key per scenario
scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        # Apply normalisation only for scenarios with variable iteration counts
        if scenario in ["no_ltn_scenario", "more_ltn_scenario"]:
            # Normalise each location's series to 100 percentage points
            normalised_lists = utils.normalise_by_percentage(lists, target_points=100)
            # Now all series have same length, can take mean
            if normalised_lists:
                arr = np.array(normalised_lists)
                scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
            else:
                scenario_dict[key] = []
        else:
            max_len = max(len(lst) for lst in lists)
            arr = np.full((len(lists), max_len), np.nan)
            for i, lst in enumerate(lists):
                arr[i, :len(lst)] = lst
            scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict


growth_orders = [("Random Growth (mean) - Seed Coverage", '--', 'blue', 'Random Growth (mean)'),
    ("Betweenness Growth - Seed Coverage", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Seed Coverage", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Seed Coverage", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Seed Coverage", '-', 'purple', 'Betweenness LTN Priority Growth')]

for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))

    # Plot random runs (grey)
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith(" - Seed Coverage"):
            plt.plot(series, color='lightgray', linewidth=1, alpha=0.4)

    # Plot strategy lines
    for key, linestyle, color, label in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel("Growth Iteration")
    plt.ylabel("Seed Coverage (count)")
    plt.title(f"Seed Point Coverage – {scenario}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "seed_coverage.png"), dpi=300)
    plt.close()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith(" - Seed Coverage")]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "seed_coverage.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %% [markdown]
# # Overlap

# %%
scenario_list_data_overlap = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            if key.endswith(" - Overlap Size Percent"):
                scenario_list_data_overlap[scenario][key].append(val)

# Compute means
scenario_overall = {}
for scenario, data in scenario_list_data_overlap.items():
    scenario_dict = {}
    for key, lists in data.items():
        # Apply normalisation only for scenarios with variable iteration counts
        if scenario in ["no_ltn_scenario", "more_ltn_scenario"]:
            # Normalise each location's series to 100 percentage points
            normalised_lists = utils.normalise_by_percentage(lists, target_points=100)
            # Now all series have same length, can take mean
            if normalised_lists:
                arr = np.array(normalised_lists)
                scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
            else:
                scenario_dict[key] = []
        else:
            max_len = max(len(lst) for lst in lists)
            arr = np.full((len(lists), max_len), np.nan)
            for i, lst in enumerate(lists):
                arr[i, :len(lst)] = lst
            scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict


growth_orders_overlap = [("Random Growth (mean) - Overlap Size Percent", '--', 'blue', 'Random Growth (mean)'),
    ("Betweenness Growth - Overlap Size Percent", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Overlap Size Percent", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Overlap Size Percent", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Overlap Size Percent", '-', 'purple', 'Betweenness LTN Priority Growth')]

# Plot and save per scenario
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))
    # Plot individual random runs in light gray
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith(" - Overlap Size Percent") and "Deviation from Random" not in key:
            plt.plot(series, color='lightgray', linewidth=1, alpha=0.4)
    for key, ls, c, lbl in growth_orders_overlap:
        if key in overall:
            plt.plot(overall[key], linestyle=ls, color=c, label=lbl)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel('Growth Iteration')
    plt.ylabel('Overlap Size (%)')
    plt.title(f'Overlap Size Percent – {scenario}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "overlap_size_percent_avg.png"), dpi=300)
    plt.close()

    # Save JSON summary
    included = [k for (k, *_ ) in growth_orders_overlap] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith(" - Overlap Size Percent") and "Deviation from Random" not in k]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "overlap_size_percent_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %%
scenario_list_data_dev = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            if key.endswith(" - Overlap Size Percent Deviation from Random"):
                scenario_list_data_dev[scenario][key].append(val)


scenario_overall_dev = {}
for scenario, data in scenario_list_data_dev.items():
    scenario_dict = {}
    for key, lists in data.items():
        max_len = max(len(lst) for lst in lists)
        arr = np.full((len(lists), max_len), np.nan)
        for i, lst in enumerate(lists):
            arr[i, :len(lst)] = lst
        scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall_dev[scenario] = scenario_dict


growth_orders_dev = [("Betweenness Growth - Overlap Size Percent Deviation from Random", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Overlap Size Percent Deviation from Random", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Overlap Size Percent Deviation from Random", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Overlap Size Percent Deviation from Random", '-', 'purple', 'Betweenness LTN Priority Growth')]

# Plot and save per scenario
for scenario in params["scenarios"]:
    overall = scenario_overall_dev.get(scenario, {})
    plt.figure(figsize=(10, 6))

    # Individual random run deviations
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith(" - Overlap Size Percent Deviation from Random"):
            plt.plot(series, color='lightgray', linewidth=1, alpha=0.4)

    # Strategy lines
    for key, ls, c, lbl in growth_orders_dev:
        if key in overall:
            plt.plot(overall[key], linestyle=ls, color=c, label=lbl)
        else:
            print(f"[Warning] {scenario} missing {key}")

    # Zero baseline
    plt.axhline(0, linestyle='--', color='blue', linewidth=1.5, label="Random Growth (mean)")


    plt.xlabel("Growth Iteration")
    plt.ylabel("Deviation from Random (%)")
    plt.title(f"Overlap Size Percent – Deviation from Random – {scenario}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "overlap_size_percent_deviation_from_random.png"), dpi=300)
    plt.show()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders_dev] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith(" - Overlap Size Percent Deviation from Random")]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "overlap_size_percent_deviation_from_random.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %% [markdown]
# # Directness

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():  # only series
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            if key.endswith(" - Directness"):
                scenario_list_data[scenario][key].append(val)


scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        # Apply normalization only for scenarios with variable iteration counts
        if scenario in ["no_ltn_scenario", "more_ltn_scenario"]:
            # Normalize each location's series to 100 percentage points
            normalised_lists = utils.normalise_by_percentage(lists, target_points=100)
            
            # Now all series have same length, can take mean
            if normalised_lists:
                arr = np.array(normalised_lists)
                scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
            else:
                scenario_dict[key] = []
        else:
            # Use original padding method for other scenarios
            max_len = max(len(lst) for lst in lists)
            arr = np.full((len(lists), max_len), np.nan)
            for i, lst in enumerate(lists):
                arr[i, :len(lst)] = lst
            scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict

# Define plotting order
growth_orders = [("Random Growth (mean) - Directness", '--', 'blue', 'Random Growth (mean)'),
    ("Betweenness Growth - Directness", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Directness", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Directness", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Directness", '-', 'purple', 'Betweenness LTN Priority Growth')]

# Plot and save
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith(" - Directness"):
            plt.plot(series, color='lightgray', linewidth=1, alpha=0.4)

    for key, ls, c, lbl in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=ls, color=c, label=lbl)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel('Growth Iteration')
    plt.ylabel('Directness (Average Ratio)')
    plt.title(f'Directness – {scenario}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "directness_avg.png"), dpi=300)
    plt.close()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith(" - Directness")]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "directness_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %% [markdown]
# # Effieciency

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():  # only time-series
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            if key.endswith(" - Global Efficiency"):
                scenario_list_data[scenario][key].append(val)


scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        # Apply normalization only for scenarios with variable iteration counts
        if scenario in ["no_ltn_scenario", "more_ltn_scenario"]:
            # Normalize each location's series to 100 percentage points
            normalised_lists = utils.normalise_by_percentage(lists, target_points=100)
            
            # Now all series have same length, can take mean
            if normalised_lists:
                arr = np.array(normalised_lists)
                scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
            else:
                scenario_dict[key] = []
        else:
            # Use original padding method for other scenarios
            max_len = max(len(lst) for lst in lists)
            arr = np.full((len(lists), max_len), np.nan)
            for i, lst in enumerate(lists):
                arr[i, :len(lst)] = lst
            scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict


growth_orders = [("Random Growth (mean) - Global Efficiency", '--', 'blue', 'Random Growth (mean)'),
    ("Betweenness Growth - Global Efficiency", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Global Efficiency", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Global Efficiency", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Global Efficiency", '-', 'purple', 'Betweenness LTN Priority Growth')]

# Plot and save per scenario
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith(" - Global Efficiency"):
            plt.plot(series, color='lightgray', linewidth=1, alpha=0.4)

    for key, ls, c, lbl in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=ls, color=c, label=lbl)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel('Growth Iteration')
    plt.ylabel('Global Efficiency')
    plt.title(f'Global Efficiency – {scenario}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "global_efficiency_avg.png"), dpi=300)
    plt.close()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith(" - Global Efficiency")]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "global_efficiency_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():  # only time-series
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            if key.endswith(" - Local Efficiency"):
                scenario_list_data[scenario][key].append(val)


scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        # Apply normalization only for scenarios with variable iteration counts
        if scenario in ["no_ltn_scenario", "more_ltn_scenario"]:
            # Normalize each location's series to 100 percentage points
            normalised_lists = utils.normalise_by_percentage(lists, target_points=100)
            
            # Now all series have same length, can take mean
            if normalised_lists:
                arr = np.array(normalised_lists)
                scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
            else:
                scenario_dict[key] = []
        else:
            # Use original padding method for other scenarios
            max_len = max(len(lst) for lst in lists)
            arr = np.full((len(lists), max_len), np.nan)
            for i, lst in enumerate(lists):
                arr[i, :len(lst)] = lst
            scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict

growth_orders = [("Random Growth (mean) - Local Efficiency", '--', 'blue', 'Random Growth (mean)'),
    ("Betweenness Growth - Local Efficiency", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Local Efficiency", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Local Efficiency", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Local Efficiency", '-', 'purple', 'Betweenness LTN Priority Growth'),]

# Plot and save per scenario
for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith(" - Local Efficiency"):
            plt.plot(series, color='lightgray', linewidth=1, alpha=0.4)
    for key, ls, c, lbl in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=ls, color=c, label=lbl)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel('Growth Iteration')
    plt.ylabel('Local Efficiency')
    plt.title(f'Local Efficiency – {scenario}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "local_efficiency_avg.png"), dpi=300)
    plt.close()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith(" - Local Efficiency")]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "local_efficiency_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %% [markdown]
# # Node Degree

# %%
# current ltn scenario random runs are way off after run 87??

scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():  # only time-series
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            if key.endswith(" - Avg Node Degree"):
                scenario_list_data[scenario][key].append(val)


scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        # Apply normalization only for scenarios with variable iteration counts
        if scenario in ["no_ltn_scenario", "more_ltn_scenario"]:
            # Normalize each location's series to 100 percentage points
            normalised_lists = utils.normalise_by_percentage(lists, target_points=100)
            
            # Now all series have same length, can take mean
            if normalised_lists:
                arr = np.array(normalised_lists)
                scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
            else:
                scenario_dict[key] = []
        else:
            # Use original padding method for other scenarios
            max_len = max(len(lst) for lst in lists)
            arr = np.full((len(lists), max_len), np.nan)
            for i, lst in enumerate(lists):
                arr[i, :len(lst)] = lst
            scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict


# Plotting and saving for Avg Node Degree
growth_orders_degree = [("Random Growth (mean) - Avg Node Degree", '--', 'blue', 'Random Growth (mean)'),
    ("Betweenness Growth - Avg Node Degree", '-', 'orange', 'Betweenness Growth'),
    ("Demand Growth - Avg Node Degree", '-.', 'red', 'Demand Growth'),
    ("Demand LTN Priority Growth - Avg Node Degree", ':', 'green', 'Demand LTN Priority Growth'),
    ("Betweenness LTN Priority Growth - Avg Node Degree", '-', 'purple', 'Betweenness LTN Priority Growth')]

for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))

    # Plot random runs
    count = 0
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith(" - Avg Node Degree"):
            if count < 87:
                plt.plot(series, color='lightgray', linewidth=1, alpha=0.4)
                count += 1
            else:
                break

    # Plot strategy curves
    for key, linestyle, color, label in growth_orders_degree:
        if key in overall:
            plt.plot(overall[key], linestyle=linestyle, color=color, label=label)
        else:
            print(f"[Warning] {scenario} missing {key}")

    plt.xlabel("Growth Iteration")
    plt.ylabel("Average Node Degree")
    plt.title(f"Avg Node Degree – {scenario}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()

    # Save plot
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "avg_node_degree.png"), dpi=300)
    plt.show()

    # Save JSON
    included = [k for (k, *_ ) in growth_orders_degree] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith(" - Avg Node Degree")]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "avg_node_degree.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %% [markdown]
# # Bikeability

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            if key.endswith(" - Bikeability Flow %"):
                scenario_list_data[scenario][key].append(val)

scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        if scenario in ["no_ltn_scenario", "more_ltn_scenario"]:
            normalised_lists = utils.normalise_by_percentage(lists, target_points=100)
            if normalised_lists:
                arr = np.array(normalised_lists)
                scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
            else:
                scenario_dict[key] = []
        else:
            max_len = max(len(lst) for lst in lists)
            arr = np.full((len(lists), max_len), np.nan)
            for i, lst in enumerate(lists):
                arr[i, :len(lst)] = lst
            scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict

growth_orders = [
    ("Random Growth (mean) - Bikeability Flow %", "--", "blue", "Random Growth (mean)"),
    ("Betweenness Growth - Bikeability Flow %", "-", "orange", "Betweenness Growth"),
    ("Demand Growth - Bikeability Flow %", "-.", "red", "Demand Growth"),
    ("Demand LTN Priority Growth - Bikeability Flow %", ":", "green", "Demand LTN Priority Growth"),
    ("Betweenness LTN Priority Growth - Bikeability Flow %", "-", "purple", "Betweenness LTN Priority Growth"),
]

for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith(" - Bikeability Flow %"):
            plt.plot(series, color="lightgray", linewidth=1, alpha=0.4)
    for key, ls, c, lbl in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=ls, color=c, label=lbl)
        else:
            print(f"[Warning] {scenario} missing {key}")
    plt.xlabel("Growth Iteration")
    plt.ylabel("Bikeable Flow (%)")
    plt.title(f"Bikeability Flow % – {scenario}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "bikeability_flow_pct_avg.png"), dpi=300)
    plt.close()
    included = [k for (k, *_) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith(" - Bikeability Flow %")]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "bikeability_flow_pct_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            if key.endswith(" - Bikeability Pairs %"):
                scenario_list_data[scenario][key].append(val)

scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        if scenario in ["no_ltn_scenario", "more_ltn_scenario"]:
            normalised_lists = utils.normalise_by_percentage(lists, target_points=100)
            if normalised_lists:
                arr = np.array(normalised_lists)
                scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
            else:
                scenario_dict[key] = []
        else:
            max_len = max(len(lst) for lst in lists)
            arr = np.full((len(lists), max_len), np.nan)
            for i, lst in enumerate(lists):
                arr[i, :len(lst)] = lst
            scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict

growth_orders = [
    ("Random Growth (mean) - Bikeability Pairs %", "--", "blue", "Random Growth (mean)"),
    ("Betweenness Growth - Bikeability Pairs %", "-", "orange", "Betweenness Growth"),
    ("Demand Growth - Bikeability Pairs %", "-.", "red", "Demand Growth"),
    ("Demand LTN Priority Growth - Bikeability Pairs %", ":", "green", "Demand LTN Priority Growth"),
    ("Betweenness LTN Priority Growth - Bikeability Pairs %", "-", "purple", "Betweenness LTN Priority Growth"),
]

for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith(" - Bikeability Pairs %"):
            plt.plot(series, color="lightgray", linewidth=1, alpha=0.4)
    for key, ls, c, lbl in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=ls, color=c, label=lbl)
        else:
            print(f"[Warning] {scenario} missing {key}")
    plt.xlabel("Growth Iteration")
    plt.ylabel("Bikeable Pairs (%)")
    plt.title(f"Bikeability Pairs % – {scenario}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "bikeability_pairs_pct_avg.png"), dpi=300)
    plt.close()
    included = [k for (k, *_) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith(" - Bikeability Pairs %")]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "bikeability_pairs_pct_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            if key.endswith(" - Bikeability Flow"):
                scenario_list_data[scenario][key].append(val)

scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        if scenario in ["no_ltn_scenario", "more_ltn_scenario"]:
            normalised_lists = utils.normalise_by_percentage(lists, target_points=100)
            if normalised_lists:
                arr = np.array(normalised_lists)
                scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
            else:
                scenario_dict[key] = []
        else:
            max_len = max(len(lst) for lst in lists)
            arr = np.full((len(lists), max_len), np.nan)
            for i, lst in enumerate(lists):
                arr[i, :len(lst)] = lst
            scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict

growth_orders = [
    ("Random Growth (mean) - Bikeability Flow", "--", "blue", "Random Growth (mean)"),
    ("Betweenness Growth - Bikeability Flow", "-", "orange", "Betweenness Growth"),
    ("Demand Growth - Bikeability Flow", "-.", "red", "Demand Growth"),
    ("Demand LTN Priority Growth - Bikeability Flow", ":", "green", "Demand LTN Priority Growth"),
    ("Betweenness LTN Priority Growth - Bikeability Flow", "-", "purple", "Betweenness LTN Priority Growth"),
]

for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith(" - Bikeability Flow"):
            plt.plot(series, color="lightgray", linewidth=1, alpha=0.4)
    for key, ls, c, lbl in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=ls, color=c, label=lbl)
        else:
            print(f"[Warning] {scenario} missing {key}")
    plt.xlabel("Growth Iteration")
    plt.ylabel("Bikeable Flow (abs.)")
    plt.title(f"Bikeability Flow – {scenario}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "bikeability_flow_avg.png"), dpi=300)
    plt.close()
    included = [k for (k, *_) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith(" - Bikeability Flow")]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "bikeability_flow_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            if key.endswith(" - Bikeability Pairs"):
                scenario_list_data[scenario][key].append(val)

scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        if scenario in ["no_ltn_scenario", "more_ltn_scenario"]:
            normalised_lists = utils.normalise_by_percentage(lists, target_points=100)
            if normalised_lists:
                arr = np.array(normalised_lists)
                scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
            else:
                scenario_dict[key] = []
        else:
            max_len = max(len(lst) for lst in lists)
            arr = np.full((len(lists), max_len), np.nan)
            for i, lst in enumerate(lists):
                arr[i, :len(lst)] = lst
            scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict

growth_orders = [
    ("Random Growth (mean) - Bikeability Pairs", "--", "blue", "Random Growth (mean)"),
    ("Betweenness Growth - Bikeability Pairs", "-", "orange", "Betweenness Growth"),
    ("Demand Growth - Bikeability Pairs", "-.", "red", "Demand Growth"),
    ("Demand LTN Priority Growth - Bikeability Pairs", ":", "green", "Demand LTN Priority Growth"),
    ("Betweenness LTN Priority Growth - Bikeability Pairs", "-", "purple", "Betweenness LTN Priority Growth"),
]

for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith(" - Bikeability Pairs"):
            plt.plot(series, color="lightgray", linewidth=1, alpha=0.4)
    for key, ls, c, lbl in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=ls, color=c, label=lbl)
        else:
            print(f"[Warning] {scenario} missing {key}")
    plt.xlabel("Growth Iteration")
    plt.ylabel("Bikeable Pairs (abs.)")
    plt.title(f"Bikeability Pairs – {scenario}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "bikeability_pairs_avg.png"), dpi=300)
    plt.close()
    included = [k for (k, *_) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith(" - Bikeability Pairs")]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "bikeability_pairs_avg.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %% [markdown]
# # Street Coverage (m)

# %%
scenario_list_data = defaultdict(lambda: defaultdict(list))
for res in results_list:
    scenario = res["scenario"]
    for key, val in res.items():
        if isinstance(val, list) and all(isinstance(v, (int, float, np.number)) for v in val if v is not None):
            if key.endswith(" - Street Coverage m"):
                scenario_list_data[scenario][key].append(val)

scenario_overall = {}
for scenario, data in scenario_list_data.items():
    scenario_dict = {}
    for key, lists in data.items():
        if scenario in ["no_ltn_scenario", "more_ltn_scenario"]:
            normalised_lists = utils.normalise_by_percentage(lists, target_points=100)
            if normalised_lists:
                arr = np.array(normalised_lists)
                scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
            else:
                scenario_dict[key] = []
        else:
            max_len = max(len(lst) for lst in lists)
            arr = np.full((len(lists), max_len), np.nan)
            for i, lst in enumerate(lists):
                arr[i, :len(lst)] = lst
            scenario_dict[key] = np.nanmean(arr, axis=0).tolist()
    scenario_overall[scenario] = scenario_dict

growth_orders = [
    ("Random Growth (mean) - Street Coverage m", "--", "blue", "Random Growth (mean)"),
    ("Betweenness Growth - Street Coverage m", "-", "orange", "Betweenness Growth"),
    ("Demand Growth - Street Coverage m", "-.", "red", "Demand Growth"),
    ("Demand LTN Priority Growth - Street Coverage m", ":", "green", "Demand LTN Priority Growth"),
    ("Betweenness LTN Priority Growth - Street Coverage m", "-", "purple", "Betweenness LTN Priority Growth"),
]

for scenario in params["scenarios"]:
    overall = scenario_overall.get(scenario, {})
    plt.figure(figsize=(10, 6))
    for key, series in overall.items():
        if key.startswith("Random Run") and key.endswith(" - Street Coverage m"):
            plt.plot(series, color="lightgray", linewidth=1, alpha=0.4)
    for key, ls, c, lbl in growth_orders:
        if key in overall:
            plt.plot(overall[key], linestyle=ls, color=c, label=lbl)
        else:
            print(f"[Warning] {scenario} missing {key}")
    plt.xlabel("Growth Iteration")
    plt.ylabel("Street Coverage (m)")
    plt.title(f"Street Coverage (m) – {scenario}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    fp = PATH["plots_overall_results"][scenario]
    plt.savefig(os.path.join(fp, "street_coverage_m.png"), dpi=300)
    plt.close()
    included = [k for (k, *_) in growth_orders] + \
               [k for k in overall if k.startswith("Random Run") and k.endswith(" - Street Coverage m")]
    summary = {k: overall[k] for k in included if k in overall}
    with open(os.path.join(PATH["overall_results"][scenario], "street_coverage_m.json"), "w") as f:
        json.dump(summary, f, indent=2)

# %% [markdown]
# # AUC Cross-location Aggregation

# %%
# Load per-place AUC summary CSVs produced by notebook 05
auc_dfs = []
for fp in Path(PATH["results"]).rglob("*_auc_summary_long.csv"):
    df = pd.read_csv(fp)
    df["placeid"] = fp.parent.name
    auc_dfs.append(df)

if auc_dfs:
    overall_auc = pd.concat(auc_dfs, ignore_index=True)

    # Aggregate across locations
    auc_cross = (
        overall_auc
        .groupby(["scenario", "metric", "method"])["auc"]
        .agg(mean_auc="mean", std_auc="std", n_places="count")
        .reset_index()
    )
    auc_cross_path = os.path.join(PATH["results"], "overall_auc_cross_location.csv")
    auc_cross.to_csv(auc_cross_path, index=False)
    print(f"Saved cross-location AUC table -> {auc_cross_path}")

    method_order = [
        "Demand Growth", "Betweenness Growth",
        "Demand LTN Priority Growth", "Betweenness LTN Priority Growth",
        "Random Growth (mean)",
    ]

    for scenario in params["scenarios"]:
        df_s = auc_cross[auc_cross["scenario"] == scenario].copy()
        if df_s.empty:
            print(f"[Warning] No AUC data for {scenario}")
            continue

        pivot = df_s.pivot_table(index="metric", columns="method", values="mean_auc")
        col_order = [c for c in method_order if c in pivot.columns]
        pivot = pivot[col_order]

        fig, ax = plt.subplots(figsize=(max(8, len(col_order)*2), max(5, len(pivot)*0.5 + 2)))
        im = ax.imshow(pivot.values, aspect="auto", cmap="YlGn")
        plt.colorbar(im, ax=ax, label="Mean AUC (across locations)")
        ax.set_xticks(range(len(pivot.columns)))
        ax.set_xticklabels(pivot.columns, rotation=30, ha="right", fontsize=9)
        ax.set_yticks(range(len(pivot.index)))
        ax.set_yticklabels(pivot.index, fontsize=9)
        ax.set_title(f"Cross-location Mean AUC – {scenario}", fontsize=12)
        plt.tight_layout()
        out_dir = os.path.join(PATH["plots"], "overall_results", scenario)
        os.makedirs(out_dir, exist_ok=True)
        plt.savefig(os.path.join(out_dir, "auc_cross_location_heatmap.png"), dpi=300)
        plt.close()
        print(f"Saved AUC heatmap for {scenario}")

    # Also load pct-vs-random CSVs if available
    pct_dfs = []
    for fp in Path(PATH["results"]).rglob("*_auc_vs_random_pct_long.csv"):
        df = pd.read_csv(fp)
        df["placeid"] = fp.parent.name
        pct_dfs.append(df)
    if pct_dfs:
        overall_pct = pd.concat(pct_dfs, ignore_index=True)
        pct_cross = (
            overall_pct
            .groupby(["scenario", "metric", "method"])["pct_vs_random"]
            .agg(mean_pct="mean", std_pct="std", n_places="count")
            .reset_index()
        )
        pct_cross_path = os.path.join(PATH["results"], "overall_auc_pct_vs_random_cross_location.csv")
        pct_cross.to_csv(pct_cross_path, index=False)
        print(f"Saved cross-location AUC % vs random -> {pct_cross_path}")
else:
    print("[Warning] No *_auc_summary_long.csv files found. Run notebook 05 first.")

# %% [markdown]
# ## Build matrix plot

# %%
scenarios = list(scenario_overall.keys())
# order matters here
plot_files = [
    "cycleLengths_avg.png",
    "allLengths_avg.png",
    "loInvestment_avg.png",
    "RequiredloInvestment_avg.png",
    "RequiredloInvestment_dev_from_random.png",
    "length_difference_avg.png",
    "length_difference_absdev.png",
    "connected_biketrack_avg.png",
    "connected_biketrack_deviation_avg.png",
    "lcc_length_avg.png",
    "composite_lcc_length_avg.png",
    "composite_lcc_length_deviation_avg.png",
    "num_components_avg.png",
    "num_components_deviation_avg.png",
    "street_coverage_pct.png",
    "street_coverage_m.png",
    "overlap_size_percent_avg.png",
    "overlap_size_percent_deviation_from_random.png",
    "directness_avg.png",
    "global_efficiency_avg.png",
    "local_efficiency_avg.png",
    "avg_node_degree.png",
    "bikeability_flow_pct_avg.png",
    "bikeability_pairs_pct_avg.png",
    "bikeability_flow_avg.png",
    "bikeability_pairs_avg.png",
]

row_labels = [ "Cycle Lengths", "All Lengths", "Investment Length", "Required Investment", "Required Investment Deviation",
    "Length Difference", "Length Diff. AbsDev", "Connected Biketrack", "Connected Biketrack Deviation",
    "LCC Length", "LCC Length Deviation", "Composite LCC Length", "Composite LCC Deviation",
    "Num Components", "Num Components Deviation", "Street Coverage (%)", "Street Coverage (m)",
    "Overlap (%)", "Overlap Deviation", "Directness", "Global Efficiency", "Local Efficiency", "Avg Node Degree",
    "Bikeability Flow (%)", "Bikeability Pairs (%)", "Bikeability Flow (abs.)", "Bikeability Pairs (abs.)",
]

n_rows = len(plot_files)
n_cols = len(scenarios)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(3*n_cols+2, 2*n_rows+2))

for row, (plot_file, row_label) in enumerate(zip(plot_files, row_labels)):
    for col, scenario in enumerate(scenarios):
        ax = axes[row, col] if n_rows > 1 else axes[col]
        plot_path = os.path.join(PATH["plots_overall_results"][scenario], plot_file)
        if os.path.exists(plot_path):
            img = mpimg.imread(plot_path)
            ax.imshow(img)
            ax.axis('off')
        else:
            ax.text(0.5, 0.5, "Missing", ha="center", va="center", fontsize=10)
            ax.axis('off')
        if row == 0:
            ax.set_title(scenario.replace("_", " ").title(), fontsize=12)
    # Row labels
    axes[row, 0].set_ylabel(row_label, fontsize=10, rotation=0, labelpad=60, va='center')

plt.tight_layout()
plt.suptitle("Scenario Matrix Plot – All Metrics", fontsize=16, y=1.02)
plt.subplots_adjust(top=0.96)
plt.savefig(os.path.join(PATH["plots"], "overall_results", "matrix_plot_all_metrics.png"), dpi=800)
plt.show()

# %% [markdown]
# # Scenario comparisons

# %% [markdown]
# In order to understand the impact of LTNs on the cycle network, we can compare the results of our three scenarios (No low traffic neighbourhoods, current best estimate of low traffic neighbourhoods, potential future low traffic neighbourhoods). This analysis is split into two parts:
# - Comparing the network metrics between scenarios
# - Identifying where redundancy occurs
